# %% [markdown]
# # Exam Project - Scraping BoligPortalen

# %%
# Import packages:
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import tqdm
import time

# Import packages:
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm  # Import tqdm for the progress bar

# Define function to get the data from the website: BoligPortal 
def scrape_data(offset):
    # Define the base URL:
    base_url = 'https://www.boligportal.dk/lejeboliger/?min_rental_period=0&offset={}'

    # Create the complete URL with the given offset:
    url = base_url.format(offset)

    # Connect to site:
    response = requests.get(url, headers={'name':'Jesper Højberg Knudsen','email':'fmw786@econ.ku.dk'})

    # Parse data with BeautifulSoup:
    soup = BeautifulSoup(response.content, 'lxml')

    # Find all links to the individual ads:
    links = soup.find_all('a', class_='AdCardSrp__Link css-17x8ssx')

    # Make a list of URLs:
    url_list = [link['href'] for link in links]

    # Return the 4th to 21st URLs (indices 3 to 20)
    return url_list[3:21]

# Set the initial offset and the step size:
initial_offset = 0
step_size = 18

# Define the number of iterations you want to perform:
num_iterations = 20  # You can change this as needed ændre til 952 eller lignende

# Create an empty list to store all URLs:
all_urls = []

# Loop through the desired number of iterations:
for i in tqdm(range(num_iterations), desc="Scraping URLs"):  # Use tqdm for progress bar
    offset = initial_offset + (i * step_size)
    urls = scrape_data(offset)
    all_urls.extend(urls)

# Make final list of working URLs:
final_urls = []

for url in all_urls:
    temp_url = 'https://www.boligportal.dk' + url
    final_urls.append(temp_url)

# Print all final scraped URLs:
for url in final_urls:
    print(url)
# Out:
# Scraping URLs: 100%|██████████| 20/20 [00:42<00:00,  2.11s/it]
# https://www.boligportal.dk/lejligheder/aalborg/60m2-2-vaer-id-5378511
# https://www.boligportal.dk/lejligheder/aalborg/64m2-2-vaer-id-5378510
# https://www.boligportal.dk/lejligheder/aalborg/66m2-2-vaer-id-1853477
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/50m2-2-vaer-id-5235577
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/79m2-3-vaer-id-4221541
# https://www.boligportal.dk/lejligheder/nyborg/56m2-3-vaer-id-4530509
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/68m2-3-vaer-id-5378508
# https://www.boligportal.dk/lejligheder/nyborg/61m2-1-vaer-id-1397835
# https://www.boligportal.dk/v%C3%A6relser/aarhus/14m2-1-vaer-id-4977665
# https://www.boligportal.dk/lejligheder/slagelse/50m2-1-vaer-id-4540921
# https://www.boligportal.dk/lejligheder/aalborg/47m2-2-vaer-id-3928432
# https://www.boligportal.dk/lejligheder/brande/87m2-2-vaer-id-5378506
# https://www.boligportal.dk/lejligheder/slagelse/50m2-2-vaer-id-5248195
# https://www.boligportal.dk/lejligheder/esbjerg/65m2-2-vaer-id-4623443
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/119m2-4-vaer-id-4998849
# https://www.boligportal.dk/lejligheder/aarhus/83m2-3-vaer-id-5319427
# https://www.boligportal.dk/lejligheder/aarhus/39m2-2-vaer-id-5312334
# https://www.boligportal.dk/lejligheder/aarhus/67m2-3-vaer-id-5257316
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/206m2-8-vaer-id-5378503
# https://www.boligportal.dk/huse/b%C3%B8rkop/101m2-4-vaer-id-5273574
# https://www.boligportal.dk/huse/b%C3%B8rkop/81m2-3-vaer-id-5378502
# https://www.boligportal.dk/r%C3%A6kkehuse/b%C3%B8rkop/112m2-4-vaer-id-5325536
# https://www.boligportal.dk/r%C3%A6kkehuse/odense/106m2-3-vaer-id-5378501
# https://www.boligportal.dk/lejligheder/odense/90m2-4-vaer-id-5270626
# https://www.boligportal.dk/r%C3%A6kkehuse/gudme/100m2-4-vaer-id-5348670
# https://www.boligportal.dk/lejligheder/horsens/91m2-4-vaer-id-4584079
# https://www.boligportal.dk/lejligheder/aalborg/78m2-2-vaer-id-5011813
# https://www.boligportal.dk/lejligheder/b%C3%B8rkop/72m2-2-vaer-id-5286709
# https://www.boligportal.dk/v%C3%A6relser/k%C3%B8benhavn/15m2-1-vaer-id-5378464
# https://www.boligportal.dk/lejligheder/odense/37m2-1-vaer-id-5378500
# https://www.boligportal.dk/lejligheder/kolding/103m2-3-vaer-id-4772937
# https://www.boligportal.dk/r%C3%A6kkehuse/niv%C3%A5/113m2-4-vaer-id-5312065
# https://www.boligportal.dk/lejligheder/sor%C3%B8/60m2-2-vaer-id-2964555
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/87m2-3-vaer-id-5369269
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/91m2-3-vaer-id-5362439
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/85m2-3-vaer-id-5359550
# https://www.boligportal.dk/lejligheder/aalborg/104m2-4-vaer-id-5378498
# https://www.boligportal.dk/lejligheder/odense/48m2-2-vaer-id-5378497
# https://www.boligportal.dk/lejligheder/aalborg/35m2-1-vaer-id-5378496
# https://www.boligportal.dk/lejligheder/aalborg/45m2-2-vaer-id-5378495
# https://www.boligportal.dk/lejligheder/aalborg/63m2-2-vaer-id-5378494
# https://www.boligportal.dk/lejligheder/aalborg/54m2-2-vaer-id-5378493
# https://www.boligportal.dk/lejligheder/aalborg/54m2-2-vaer-id-5378492
# https://www.boligportal.dk/lejligheder/aalborg/48m2-2-vaer-id-5378491
# https://www.boligportal.dk/lejligheder/aalborg/54m2-2-vaer-id-5357559
# https://www.boligportal.dk/lejligheder/aalborg/60m2-2-vaer-id-5378490
# https://www.boligportal.dk/lejligheder/aalborg/54m2-2-vaer-id-5378488
# https://www.boligportal.dk/lejligheder/aalborg/75m2-3-vaer-id-5378487
# https://www.boligportal.dk/lejligheder/holsted/80m2-3-vaer-id-4453750
# https://www.boligportal.dk/lejligheder/kolding/93m2-3-vaer-id-963079
# https://www.boligportal.dk/v%C3%A6relser/k%C3%B8benhavn/18m2-1-vaer-id-5378462
# https://www.boligportal.dk/lejligheder/aarhus/83m2-3-vaer-id-5319427
# https://www.boligportal.dk/lejligheder/aarhus/39m2-2-vaer-id-5312334
# https://www.boligportal.dk/lejligheder/aarhus/67m2-3-vaer-id-5257316
# https://www.boligportal.dk/r%C3%A6kkehuse/n%C3%A6stved/134m2-4-vaer-id-5378433
# https://www.boligportal.dk/lejligheder/haslev/66m2-2-vaer-id-5180372
# https://www.boligportal.dk/lejligheder/s%C3%B8nderborg/77m2-3-vaer-id-5378486
# https://www.boligportal.dk/lejligheder/aarhus/78m2-2-vaer-id-5263448
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/97m2-4-vaer-id-5378485
# https://www.boligportal.dk/r%C3%A6kkehuse/ansager/104m2-3-vaer-id-5205923
# https://www.boligportal.dk/lejligheder/helsing%C3%B8r/115m2-4-vaer-id-5378484
# https://www.boligportal.dk/r%C3%A6kkehuse/silkeborg/108m2-4-vaer-id-5378483
# https://www.boligportal.dk/r%C3%A6kkehuse/kolding/100m2-3-vaer-id-5328886
# https://www.boligportal.dk/r%C3%A6kkehuse/silkeborg/113m2-4-vaer-id-5378482
# https://www.boligportal.dk/lejligheder/randers/94m2-3-vaer-id-5172934
# https://www.boligportal.dk/lejligheder/odense/38m2-1-vaer-id-5378481
# https://www.boligportal.dk/r%C3%A6kkehuse/silkeborg/113m2-4-vaer-id-5378480
# https://www.boligportal.dk/lejligheder/haderslev/74m2-2-vaer-id-4744426
# https://www.boligportal.dk/lejligheder/stenstrup/64m2-2-vaer-id-5378277
# https://www.boligportal.dk/lejligheder/aarhus/83m2-3-vaer-id-5319427
# https://www.boligportal.dk/lejligheder/aarhus/39m2-2-vaer-id-5312334
# https://www.boligportal.dk/lejligheder/aarhus/67m2-3-vaer-id-5257316
# https://www.boligportal.dk/lejligheder/haderslev/66m2-2-vaer-id-3594569
# https://www.boligportal.dk/lejligheder/randers/85m2-3-vaer-id-5378475
# https://www.boligportal.dk/lejligheder/borre/57m2-2-vaer-id-5179265
# https://www.boligportal.dk/lejligheder/haderslev/77m2-3-vaer-id-4002757
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/131m2-5-vaer-id-5037726
# https://www.boligportal.dk/v%C3%A6relser/aarhus/10m2-1-vaer-id-5378152
# https://www.boligportal.dk/huse/haarby/160m2-5-vaer-id-3936234
# https://www.boligportal.dk/lejligheder/roskilde/100m2-4-vaer-id-5241048
# https://www.boligportal.dk/lejligheder/kerteminde/57m2-3-vaer-id-5378473
# https://www.boligportal.dk/lejligheder/bogense/78m2-3-vaer-id-5378472
# https://www.boligportal.dk/lejligheder/bogense/79m2-3-vaer-id-5378471
# https://www.boligportal.dk/r%C3%A6kkehuse/aarhus/120m2-5-vaer-id-5378470
# https://www.boligportal.dk/r%C3%A6kkehuse/aarhus/118m2-5-vaer-id-5247564
# https://www.boligportal.dk/lejligheder/haslev/68m2-2-vaer-id-4666406
# https://www.boligportal.dk/lejligheder/rudk%C3%B8bing/80m2-2-vaer-id-5378468
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/87m2-3-vaer-id-5369269
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/91m2-3-vaer-id-5362439
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/85m2-3-vaer-id-5359550
# https://www.boligportal.dk/r%C3%A6kkehuse/k%C3%B8benhavn/169m2-6-vaer-id-5122889
# https://www.boligportal.dk/lejligheder/aarhus/83m2-3-vaer-id-5319427
# https://www.boligportal.dk/lejligheder/aarhus/39m2-2-vaer-id-5312334
# https://www.boligportal.dk/lejligheder/slagelse/74m2-2-vaer-id-3992467
# https://www.boligportal.dk/lejligheder/herning/109m2-5-vaer-id-5376634
# https://www.boligportal.dk/lejligheder/sor%C3%B8/128m2-3-vaer-id-5257780
# https://www.boligportal.dk/lejligheder/aarhus/61m2-2-vaer-id-5265445
# https://www.boligportal.dk/lejligheder/aalborg/48m2-2-vaer-id-5378459
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/87m2-3-vaer-id-5378458
# https://www.boligportal.dk/lejligheder/aarhus/67m2-3-vaer-id-5257316
# https://www.boligportal.dk/lejligheder/kolding/138m2-4-vaer-id-4879785
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/78m2-3-vaer-id-5378457
# https://www.boligportal.dk/lejligheder/aarhus/65m2-2-vaer-id-5236169
# https://www.boligportal.dk/lejligheder/t%C3%B8ll%C3%B8se/80m2-3-vaer-id-4755240
# https://www.boligportal.dk/lejligheder/aarhus/67m2-3-vaer-id-5231616
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/87m2-3-vaer-id-5369269
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/91m2-3-vaer-id-5362439
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/85m2-3-vaer-id-5359550
# https://www.boligportal.dk/lejligheder/aarhus/104m2-3-vaer-id-4177433
# https://www.boligportal.dk/lejligheder/viborg/92m2-3-vaer-id-5140441
# https://www.boligportal.dk/lejligheder/kjellerup/75m2-2-vaer-id-5224883
# https://www.boligportal.dk/lejligheder/aarhus/65m2-2-vaer-id-5240846
# https://www.boligportal.dk/lejligheder/solr%C3%B8d-strand/102m2-4-vaer-id-5252121
# https://www.boligportal.dk/lejligheder/haslev/47m2-2-vaer-id-5258181
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/100m2-3-vaer-id-4810050
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/80m2-2-vaer-id-5059584
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/89m2-3-vaer-id-4918440
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/100m2-4-vaer-id-4599619
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/104m2-4-vaer-id-5011814
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/66m2-2-vaer-id-5032976
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/89m2-3-vaer-id-4999411
# https://www.boligportal.dk/lejligheder/thybor%C3%B8n/73m2-4-vaer-id-5278699
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/113m2-5-vaer-id-5199709
# https://www.boligportal.dk/lejligheder/aarhus/83m2-3-vaer-id-5319427
# https://www.boligportal.dk/lejligheder/aarhus/39m2-2-vaer-id-5312334
# https://www.boligportal.dk/lejligheder/aarhus/67m2-3-vaer-id-5257316
# https://www.boligportal.dk/lejligheder/aarhus/105m2-4-vaer-id-5265739
# https://www.boligportal.dk/r%C3%A6kkehuse/aalborg/91m2-4-vaer-id-5378448
# https://www.boligportal.dk/lejligheder/rudk%C3%B8bing/88m2-3-vaer-id-5275450
# https://www.boligportal.dk/lejligheder/herning/81m2-3-vaer-id-4684728
# https://www.boligportal.dk/lejligheder/aalborg/64m2-2-vaer-id-4605087
# https://www.boligportal.dk/lejligheder/kolding/106m2-3-vaer-id-5253335
# https://www.boligportal.dk/lejligheder/herning/89m2-3-vaer-id-5335765
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/90m2-3-vaer-id-5378445
# https://www.boligportal.dk/r%C3%A6kkehuse/aalborg/91m2-4-vaer-id-5378444
# https://www.boligportal.dk/huse/store-heddinge/200m2-6-vaer-id-5299394
# https://www.boligportal.dk/lejligheder/lemvig/105m2-3-vaer-id-5079860
# https://www.boligportal.dk/lejligheder/herning/98m2-4-vaer-id-5378439
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/87m2-3-vaer-id-5369269
# https://www.boligportal.dk/lejligheder/horsens/70m2-2-vaer-id-5378442
# https://www.boligportal.dk/lejligheder/haderslev/107m2-3-vaer-id-5378412
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/87m2-3-vaer-id-5369269
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/91m2-3-vaer-id-5362439
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/85m2-3-vaer-id-5359550
# https://www.boligportal.dk/lejligheder/ikast/50m2-2-vaer-id-5378441
# https://www.boligportal.dk/lejligheder/aalborg/70m2-3-vaer-id-4847291
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/108m2-4-vaer-id-5272082
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/44m2-1-vaer-id-5284512
# https://www.boligportal.dk/lejligheder/aalborg/81m2-3-vaer-id-5150751
# https://www.boligportal.dk/lejligheder/kerteminde/47m2-2-vaer-id-5246886
# https://www.boligportal.dk/lejligheder/aarhus/51m2-2-vaer-id-5300706
# https://www.boligportal.dk/lejligheder/aarhus/102m2-4-vaer-id-4213031
# https://www.boligportal.dk/lejligheder/aalborg/81m2-2-vaer-id-5137464
# https://www.boligportal.dk/lejligheder/ringsted/73m2-2-vaer-id-5378440
# https://www.boligportal.dk/lejligheder/ringsted/63m2-2-vaer-id-5236277
# https://www.boligportal.dk/r%C3%A6kkehuse/odense/104m2-4-vaer-id-5352672
# https://www.boligportal.dk/lejligheder/kolding/40m2-1-vaer-id-5184479
# https://www.boligportal.dk/lejligheder/slagelse/88m2-2-vaer-id-5378438
# https://www.boligportal.dk/lejligheder/kors%C3%B8r/40m2-1-vaer-id-4015346
# https://www.boligportal.dk/lejligheder/aarhus/83m2-3-vaer-id-5319427
# https://www.boligportal.dk/lejligheder/aarhus/39m2-2-vaer-id-5312334
# https://www.boligportal.dk/lejligheder/aarhus/67m2-3-vaer-id-5257316
# https://www.boligportal.dk/lejligheder/aalborg/53m2-2-vaer-id-5209843
# https://www.boligportal.dk/lejligheder/slagelse/47m2-2-vaer-id-3947338
# https://www.boligportal.dk/lejligheder/odense/54m2-2-vaer-id-5378434
# https://www.boligportal.dk/lejligheder/ringk%C3%B8bing/36m2-2-vaer-id-5048605
# https://www.boligportal.dk/lejligheder/aarhus/106m2-4-vaer-id-5309492
# https://www.boligportal.dk/lejligheder/aarhus/66m2-1-vaer-id-4563881
# https://www.boligportal.dk/r%C3%A6kkehuse/kolding/124m2-4-vaer-id-5325309
# https://www.boligportal.dk/lejligheder/aarhus/75m2-1-vaer-id-5378431
# https://www.boligportal.dk/lejligheder/aarhus/81m2-4-vaer-id-5309482
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/45m2-1-vaer-id-5260807
# https://www.boligportal.dk/lejligheder/hammel/90m2-3-vaer-id-5300993
# https://www.boligportal.dk/r%C3%A6kkehuse/tjele/88m2-3-vaer-id-5287246
# https://www.boligportal.dk/lejligheder/viborg/65m2-2-vaer-id-5378430
# https://www.boligportal.dk/lejligheder/viborg/51m2-2-vaer-id-5280613
# https://www.boligportal.dk/lejligheder/viborg/94m2-3-vaer-id-5242768
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/87m2-3-vaer-id-5369269
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/91m2-3-vaer-id-5362439
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/85m2-3-vaer-id-5359550
# https://www.boligportal.dk/r%C3%A6kkehuse/ans-by/109m2-4-vaer-id-5346253
# https://www.boligportal.dk/lejligheder/sk%C3%A6lsk%C3%B8r/66m2-2-vaer-id-4964804
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/74m2-3-vaer-id-5378427
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/94m2-4-vaer-id-5022004
# https://www.boligportal.dk/lejligheder/helsing%C3%B8r/82m2-3-vaer-id-5262346
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/83m2-3-vaer-id-4584739
# https://www.boligportal.dk/lejligheder/randers/68m2-2-vaer-id-5230046
# https://www.boligportal.dk/lejligheder/helsing%C3%B8r/82m2-3-vaer-id-5263261
# https://www.boligportal.dk/lejligheder/aalborg/49m2-2-vaer-id-5378426
# https://www.boligportal.dk/r%C3%A6kkehuse/horsens/97m2-4-vaer-id-5378424
# https://www.boligportal.dk/lejligheder/br%C3%B8nderslev/145m2-4-vaer-id-5378423
# https://www.boligportal.dk/r%C3%A6kkehuse/kib%C3%A6k/98m2-3-vaer-id-5378422
# https://www.boligportal.dk/lejligheder/frederikshavn/100m2-4-vaer-id-4107043
# https://www.boligportal.dk/r%C3%A6kkehuse/herning/113m2-3-vaer-id-5223382
# https://www.boligportal.dk/r%C3%A6kkehuse/herning/113m2-3-vaer-id-5378421
# https://www.boligportal.dk/lejligheder/aarhus/83m2-3-vaer-id-5319427
# https://www.boligportal.dk/lejligheder/aarhus/39m2-2-vaer-id-5312334
# https://www.boligportal.dk/lejligheder/aarhus/67m2-3-vaer-id-5257316
# https://www.boligportal.dk/lejligheder/aarhus/61m2-2-vaer-id-5242001
# https://www.boligportal.dk/lejligheder/frederikshavn/55m2-2-vaer-id-5053873
# https://www.boligportal.dk/lejligheder/vejle/92m2-2-vaer-id-3744308
# https://www.boligportal.dk/huse/f%C3%A5rup/101m2-4-vaer-id-5378416
# https://www.boligportal.dk/lejligheder/aarhus/64m2-2-vaer-id-5227917
# https://www.boligportal.dk/lejligheder/randers/87m2-3-vaer-id-4554905
# https://www.boligportal.dk/lejligheder/hiller%C3%B8d/57m2-2-vaer-id-5378415
# https://www.boligportal.dk/lejligheder/hiller%C3%B8d/57m2-2-vaer-id-5301327
# https://www.boligportal.dk/lejligheder/aalborg/75m2-2-vaer-id-5329785
# https://www.boligportal.dk/lejligheder/aarhus/88m2-3-vaer-id-5378414
# https://www.boligportal.dk/lejligheder/herning/75m2-3-vaer-id-3693664
# https://www.boligportal.dk/lejligheder/herning/68m2-2-vaer-id-5295424
# https://www.boligportal.dk/lejligheder/vejle/40m2-1-vaer-id-2042183
# https://www.boligportal.dk/r%C3%A6kkehuse/aarhus/85m2-4-vaer-id-5275063
# https://www.boligportal.dk/lejligheder/aalborg/49m2-2-vaer-id-5378413
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/87m2-3-vaer-id-5369269
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/91m2-3-vaer-id-5362439
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/85m2-3-vaer-id-5359550
# https://www.boligportal.dk/lejligheder/aalborg/61m2-2-vaer-id-5295700
# https://www.boligportal.dk/lejligheder/hadsten/52m2-2-vaer-id-4412261
# https://www.boligportal.dk/lejligheder/stege/135m2-5-vaer-id-5140227
# https://www.boligportal.dk/lejligheder/grenaa/35m2-1-vaer-id-4369689
# https://www.boligportal.dk/lejligheder/vejle/84m2-3-vaer-id-5378411
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/59m2-2-vaer-id-3195754
# https://www.boligportal.dk/lejligheder/aalborg/70m2-2-vaer-id-5378409
# https://www.boligportal.dk/lejligheder/viborg/95m2-3-vaer-id-4113814
# https://www.boligportal.dk/r%C3%A6kkehuse/k%C3%B8benhavn/156m2-5-vaer-id-5378407
# https://www.boligportal.dk/lejligheder/aarhus/54m2-2-vaer-id-5378408
# https://www.boligportal.dk/lejligheder/aalborg/102m2-4-vaer-id-5378405
# https://www.boligportal.dk/lejligheder/n%C3%A6stved/63m2-2-vaer-id-5150925
# https://www.boligportal.dk/huse/bredsten/114m2-4-vaer-id-5378377
# https://www.boligportal.dk/lejligheder/stubbek%C3%B8bing/66m2-2-vaer-id-5314357
# https://www.boligportal.dk/lejligheder/aalborg/60m2-2-vaer-id-5378335
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/87m2-3-vaer-id-5369269
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/91m2-3-vaer-id-5362439
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/85m2-3-vaer-id-5359550
# https://www.boligportal.dk/lejligheder/hj%C3%B8rring/35m2-1-vaer-id-5378349
# https://www.boligportal.dk/lejligheder/aalborg/77m2-3-vaer-id-5378332
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/102m2-4-vaer-id-5359564
# https://www.boligportal.dk/r%C3%A6kkehuse/bryrup/101m2-5-vaer-id-5378400
# https://www.boligportal.dk/lejligheder/horsens/48m2-2-vaer-id-5378381
# https://www.boligportal.dk/lejligheder/aalborg/90m2-3-vaer-id-5378399
# https://www.boligportal.dk/lejligheder/ribe/104m2-3-vaer-id-5378368
# https://www.boligportal.dk/lejligheder/aalborg/82m2-3-vaer-id-5378398
# https://www.boligportal.dk/lejligheder/odense/69m2-3-vaer-id-5378397
# https://www.boligportal.dk/lejligheder/odense/69m2-3-vaer-id-5378396
# https://www.boligportal.dk/lejligheder/odense/91m2-4-vaer-id-5378395
# https://www.boligportal.dk/lejligheder/odense/69m2-3-vaer-id-5378394
# https://www.boligportal.dk/lejligheder/odense/69m2-3-vaer-id-5378393
# https://www.boligportal.dk/lejligheder/odense/69m2-3-vaer-id-5378392
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/149m2-5-vaer-id-5378391
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/87m2-3-vaer-id-5369269
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/91m2-3-vaer-id-5362439
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/85m2-3-vaer-id-5359550
# https://www.boligportal.dk/lejligheder/aalborg/79m2-3-vaer-id-5377865
# https://www.boligportal.dk/r%C3%A6kkehuse/k%C3%B8benhavn/117m2-4-vaer-id-5300354
# https://www.boligportal.dk/lejligheder/aarhus/57m2-2-vaer-id-5234275
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/64m2-2-vaer-id-5378388
# https://www.boligportal.dk/r%C3%A6kkehuse/k%C3%B8benhavn/109m2-4-vaer-id-5185164
# https://www.boligportal.dk/r%C3%A6kkehuse/k%C3%B8benhavn/131m2-5-vaer-id-5226226
# https://www.boligportal.dk/lejligheder/aarhus/77m2-2-vaer-id-5378387
# https://www.boligportal.dk/lejligheder/aarhus/86m2-3-vaer-id-5378386
# https://www.boligportal.dk/lejligheder/aarhus/90m2-3-vaer-id-5285092
# https://www.boligportal.dk/lejligheder/varde/46m2-1-vaer-id-5378339
# https://www.boligportal.dk/lejligheder/kolding/48m2-2-vaer-id-5378385
# https://www.boligportal.dk/v%C3%A6relser/aarhus/20m2-1-vaer-id-5378084
# https://www.boligportal.dk/v%C3%A6relser/aarhus/14m2-1-vaer-id-5378101
# https://www.boligportal.dk/lejligheder/aarhus/40m2-1-vaer-id-5172879
# https://www.boligportal.dk/v%C3%A6relser/k%C3%B8benhavn/23m2-1-vaer-id-4862503
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/87m2-3-vaer-id-5369269
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/91m2-3-vaer-id-5362439
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/85m2-3-vaer-id-5359550
# https://www.boligportal.dk/huse/esbjerg/150m2-5-vaer-id-2946504
# https://www.boligportal.dk/lejligheder/nibe/61m2-2-vaer-id-5378380
# https://www.boligportal.dk/lejligheder/aarhus/68m2-3-vaer-id-3013760
# https://www.boligportal.dk/v%C3%A6relser/aarhus/13m2-1-vaer-id-4904160
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/90m2-3-vaer-id-5294087
# https://www.boligportal.dk/lejligheder/frederikshavn/65m2-2-vaer-id-5033300
# https://www.boligportal.dk/lejligheder/aalborg/70m2-2-vaer-id-5328680
# https://www.boligportal.dk/lejligheder/aalborg/55m2-2-vaer-id-4626367
# https://www.boligportal.dk/lejligheder/videb%C3%A6k/70m2-2-vaer-id-3837007
# https://www.boligportal.dk/lejligheder/svendborg/73m2-3-vaer-id-1737914
# https://www.boligportal.dk/lejligheder/aalborg/132m2-4-vaer-id-3707968
# https://www.boligportal.dk/lejligheder/aarhus/54m2-2-vaer-id-5378379
# https://www.boligportal.dk/lejligheder/aarhus/30m2-1-vaer-id-5283482
# https://www.boligportal.dk/r%C3%A6kkehuse/ans-by/114m2-3-vaer-id-5354958
# https://www.boligportal.dk/lejligheder/aalborg/60m2-2-vaer-id-5378378
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/87m2-3-vaer-id-5369269
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/91m2-3-vaer-id-5362439
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/85m2-3-vaer-id-5359550
# https://www.boligportal.dk/lejligheder/kolding/111m2-3-vaer-id-5378333
# https://www.boligportal.dk/lejligheder/aalborg/101m2-4-vaer-id-5378375
# https://www.boligportal.dk/lejligheder/aalborg/64m2-2-vaer-id-5378374
# https://www.boligportal.dk/lejligheder/kolding/116m2-4-vaer-id-4957417
# https://www.boligportal.dk/huse/aabybro/79m2-3-vaer-id-5378369
# https://www.boligportal.dk/lejligheder/hj%C3%B8rring/50m2-2-vaer-id-5160895
# https://www.boligportal.dk/lejligheder/aarhus/32m2-1-vaer-id-4572552
# https://www.boligportal.dk/lejligheder/aarhus/79m2-3-vaer-id-5378367
# https://www.boligportal.dk/r%C3%A6kkehuse/hedensted/98m2-3-vaer-id-5350159
# https://www.boligportal.dk/lejligheder/aalborg/92m2-2-vaer-id-3210419
# https://www.boligportal.dk/lejligheder/thisted/63m2-2-vaer-id-5255117
# https://www.boligportal.dk/lejligheder/thisted/85m2-3-vaer-id-5378364
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/87m2-4-vaer-id-5289340
# https://www.boligportal.dk/lejligheder/aarhus/57m2-2-vaer-id-5346378
# https://www.boligportal.dk/lejligheder/aalborg/63m2-2-vaer-id-3488797
# https://www.boligportal.dk/lejligheder/aarhus/83m2-3-vaer-id-5319427
# https://www.boligportal.dk/lejligheder/aarhus/39m2-2-vaer-id-5312334
# https://www.boligportal.dk/lejligheder/aarhus/67m2-3-vaer-id-5257316
# https://www.boligportal.dk/lejligheder/stege/38m2-1-vaer-id-4282723
# https://www.boligportal.dk/lejligheder/aarhus/64m2-2-vaer-id-5064519
# https://www.boligportal.dk/lejligheder/randers/50m2-2-vaer-id-5378361
# https://www.boligportal.dk/lejligheder/aabenraa/35m2-1-vaer-id-4335859
# https://www.boligportal.dk/r%C3%A6kkehuse/hj%C3%B8rring/86m2-4-vaer-id-5378109
# https://www.boligportal.dk/lejligheder/svendborg/53m2-2-vaer-id-5322758
# https://www.boligportal.dk/r%C3%A6kkehuse/k%C3%B8benhavn/130m2-5-vaer-id-5378360
# https://www.boligportal.dk/lejligheder/aarhus/69m2-2-vaer-id-5378358
# https://www.boligportal.dk/lejligheder/klarup/88m2-2-vaer-id-5325569
# https://www.boligportal.dk/lejligheder/aarhus/99m2-2-vaer-id-5110272
# https://www.boligportal.dk/lejligheder/aabenraa/90m2-4-vaer-id-2992474
# https://www.boligportal.dk/lejligheder/aalborg/58m2-2-vaer-id-5378354
# https://www.boligportal.dk/lejligheder/slagelse/60m2-3-vaer-id-5000466
# https://www.boligportal.dk/lejligheder/silkeborg/99m2-3-vaer-id-5378353
# https://www.boligportal.dk/r%C3%A6kkehuse/silkeborg/114m2-4-vaer-id-5378352
# https://www.boligportal.dk/lejligheder/aarhus/83m2-3-vaer-id-5319427
# https://www.boligportal.dk/lejligheder/aarhus/39m2-2-vaer-id-5312334
# https://www.boligportal.dk/lejligheder/aarhus/67m2-3-vaer-id-5257316
# https://www.boligportal.dk/huse/kolding/170m2-7-vaer-id-4981295
# https://www.boligportal.dk/lejligheder/aalborg/60m2-2-vaer-id-5230718
# https://www.boligportal.dk/lejligheder/horsens/97m2-3-vaer-id-5317646
# https://www.boligportal.dk/lejligheder/marstal/147m2-5-vaer-id-4337270
# https://www.boligportal.dk/r%C3%A6kkehuse/silkeborg/97m2-3-vaer-id-5347000
# https://www.boligportal.dk/lejligheder/aabenraa/86m2-3-vaer-id-4602914
# https://www.boligportal.dk/lejligheder/aabenraa/98m2-3-vaer-id-4710379
# https://www.boligportal.dk/lejligheder/fjerritslev/85m2-3-vaer-id-5325286
# https://www.boligportal.dk/lejligheder/sk%C3%A5rup-fyn/23m2-1-vaer-id-5378347
# https://www.boligportal.dk/lejligheder/skive/97m2-3-vaer-id-5250465
# https://www.boligportal.dk/lejligheder/ribe/80m2-3-vaer-id-3625928
# https://www.boligportal.dk/lejligheder/t%C3%B8nder/32m2-1-vaer-id-5378334
# https://www.boligportal.dk/lejligheder/aarhus/100m2-3-vaer-id-2969023
# https://www.boligportal.dk/lejligheder/t%C3%B8nder/32m2-1-vaer-id-5378331
# https://www.boligportal.dk/lejligheder/t%C3%B8nder/32m2-1-vaer-id-5378337
# https://www.boligportal.dk/lejligheder/aarhus/83m2-3-vaer-id-5319427
# https://www.boligportal.dk/lejligheder/aarhus/39m2-2-vaer-id-5312334
# https://www.boligportal.dk/lejligheder/aarhus/67m2-3-vaer-id-5257316
# https://www.boligportal.dk/lejligheder/horsens/71m2-2-vaer-id-5378342
# https://www.boligportal.dk/lejligheder/horsens/75m2-2-vaer-id-5378341
# https://www.boligportal.dk/lejligheder/odense/66m2-2-vaer-id-5378338
# https://www.boligportal.dk/lejligheder/aarhus/110m2-3-vaer-id-4904798
# https://www.boligportal.dk/lejligheder/aarhus/41m2-1-vaer-id-4626058
# https://www.boligportal.dk/huse/ulstrup/99m2-3-vaer-id-5378250
# https://www.boligportal.dk/r%C3%A6kkehuse/k%C3%B8ge/120m2-4-vaer-id-5369216
# https://www.boligportal.dk/lejligheder/vissenbjerg/107m2-4-vaer-id-5378234
# https://www.boligportal.dk/lejligheder/holstebro/65m2-2-vaer-id-5378330
# https://www.boligportal.dk/lejligheder/silkeborg/130m2-3-vaer-id-5378325
# https://www.boligportal.dk/r%C3%A6kkehuse/herning/95m2-4-vaer-id-5259330
# https://www.boligportal.dk/r%C3%A6kkehuse/%C3%B8stbirk/70m2-2-vaer-id-5318988
# https://www.boligportal.dk/r%C3%A6kkehuse/ulstrup/90m2-4-vaer-id-5378329
# https://www.boligportal.dk/r%C3%A6kkehuse/gram/44m2-1-vaer-id-5378328
# https://www.boligportal.dk/r%C3%A6kkehuse/gram/60m2-2-vaer-id-5271041
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/87m2-3-vaer-id-5369269
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/91m2-3-vaer-id-5362439
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/85m2-3-vaer-id-5359550

# %%
# List of information we want to scarpe:
adress_list = []
monthly_rent_list = []
aconto_list = []
sqm_list = []
nr_rooms_list = []
floor_list = []
property_type_list = []
furnished_list = []
shareable_list = []
pets_allowed_list = []
elevator_list = []
senior_frendly_list = []
only_for_students_list = []
balcony_or_terrace_list = []
parking_list = []
energy_label_list = []
description_list = []

# Initialize a counter to keep track of the number of scraped URLs
scraped_count = 0

# Initialize lists to hold data for the current chunk
current_chunk = []

# Loop through all the pages
for i in tqdm(range(len(final_urls)), desc="Scraping Data"):
    # Scraping
    url = final_urls[i]
    response = requests.get(url, headers={'name':'Jesper Højberg Knudsen','email':'fmw786@econ.ku.dk'})
    soup = BeautifulSoup(response.text, 'lxml')
    
    # Adress
    # Find the label "css-11fbmqw" within the section
    element = soup.find('span', class_='css-11fbmqw')
    if element:
        # Extract the corresponding value
        adress_element = element.find_next('div', class_='css-v49nss')

        if adress_element:
            # Extract the text content and add it to the list
            adress_list.append(adress_element.text.strip())
        else:
            adress_list.append('N/A') # Handle case if the value is not found

    else:
        adress_list.append('N/A') # Handle case if the label is not found


    # Monthly rent
    # Find the label "Månedlig leje" within the section
    label_element = soup.find('span', text='Månedlig leje', class_='css-arxwps')
    
    if label_element:
        # Extract the corresponding value
        monthly_rent_element = label_element.find_next('span', class_='css-1h46kg2')
        
        if monthly_rent_element:
            # Extract the text content and add it to the list
            monthly_rent_list.append(monthly_rent_element.text.strip())
        else:
            monthly_rent_list.append('N/A')  # Handle case if the value is not found
    else:
        monthly_rent_list.append('N/A')  # Handle case if the label is not found

    # Aconto
    # Find the label "Aconto" within the section
    aconto_element = soup.find('span', class_='css-arxwps', text='Aconto')

    if aconto_element:
        # Extract the corresponding value
        aconto_element = aconto_element.find_next('span', class_='css-1h46kg2')

        if aconto_element:
            # Extract the text content and add it to the list
            aconto_list.append(aconto_element.text.strip())
        else:
            aconto_list.append('N/A')
    else:
        aconto_list.append('N/A')
        
    # Square meters
    # Find the label "Størrelse" within the section
    square_element = soup.find('span', class_='css-arxwps', text='Størrelse')

    if square_element:
        # Extract the corresponding value
        square_element = square_element.find_next('span', class_='css-1h46kg2')

        if square_element:
            # Extract the text content and add it to the list
            sqm_list.append(square_element.text.strip())
        else:
            sqm_list.append('N/A')
    else:
        sqm_list.append('N/A')


    # Number of rooms
    # Find the label "Værelser" within the section
    nr_rooms_element = soup.find('span', class_='css-arxwps', text='Værelser')

    if nr_rooms_element:
        # Extract the corresponding value
        nr_rooms_element = nr_rooms_element.find_next('span', class_='css-1h46kg2')

        if nr_rooms_element:
            # Extract the text content and add it to the list
            nr_rooms_list.append(nr_rooms_element.text.strip())
        else:
            nr_rooms_list.append('N/A')
    else:
        nr_rooms_list.append('N/A')
    
    # Floor
    # Find the label "Etage" within the section
    floor_element = soup.find('span', class_='css-arxwps', text='Etage')

    if floor_element:
        # Extract the corresponding value
        floor_element = floor_element.find_next('span', class_='css-1h46kg2')

        if floor_element:
            # Extract the text content and add it to the list
            floor_list.append(floor_element.text.strip())
        else:
            floor_list.append('N/A')
    else:
        floor_list.append('N/A')

    # Property type
    # Find the label "Boligtype" within the section
    property_type_element = soup.find('span', class_='css-arxwps', text='Boligtype')
    if property_type_element:
        # Extract the corresponding value
        property_type = property_type_element.find_next('span', class_='css-1h46kg2')
        if property_type:
            # Extract the text content and add it to the list
            property_type_list.append(property_type.text.strip())
        else:
            property_type_list.append('N/A')
    else:
        property_type_list.append('N/A')

    # Furnished
    # Find the label "Møbleret" within the section
    furnished_element = soup.find('span', class_='css-arxwps', text='Møbleret')

    if furnished_element:
        # Extract the corresponding value
        furnished_element = furnished_element.find_next('span', class_='css-1h46kg2')

        if furnished_element:
            # Extract the text content and add it to the list
            furnished_list.append(furnished_element.text.strip())
        else:
            furnished_list.append('N/A')
    else:
        furnished_list.append('N/A')

    # Shareable
    # Find the label "Delevenlig" within the section
    shareable_element = soup.find('span', class_='css-arxwps', text='Delevenlig')

    if shareable_element:
        # Extract the corresponding value
        shareable_element = shareable_element.find_next('span', class_='css-1h46kg2')

        if shareable_element:
            # Extract the text content and add it to the list
            shareable_list.append(shareable_element.text.strip())
        else:
            shareable_list.append('N/A')
    else:
        shareable_list.append('N/A')

    # Pets allowed
    # Find the label "Husdyr tilladt" within the section
    pets_allowed_element = soup.find('span', class_='css-arxwps', text='Husdyr tilladt')

    if pets_allowed_element:
        # Extract the corresponding value
        pets_allowed_element = pets_allowed_element.find_next('span', class_='css-1h46kg2')

        if pets_allowed_element:
            # Extract the text content and add it to the list
            pets_allowed_list.append(pets_allowed_element.text.strip())
        else:
            pets_allowed_list.append('N/A')
    else:
        pets_allowed_list.append('N/A')

    # elevator
    # Find the label "Elevator" within the section
    elevator_element = soup.find('span', class_='css-arxwps', text='Elevator')

    if elevator_element:
        # Extract the corresponding value
        elevator_element = elevator_element.find_next('span', class_='css-1h46kg2')

        if elevator_element:
            # Extract the text content and add it to the list
            elevator_list.append(elevator_element.text.strip())
        else:
            elevator_list.append('N/A')
    else:
        elevator_list.append('N/A')

    # Seniors frendly
    # Find the label "Seniorvenlig" within the section
    seniors_frendly_element = soup.find('span', class_='css-arxwps', text='Seniorvenlig')

    if seniors_frendly_element:
        # Extract the corresponding value
        seniors_frendly_element = seniors_frendly_element.find_next('span', class_='css-1h46kg2')

        if seniors_frendly_element:
            # Extract the text content and add it to the list
            senior_frendly_list.append(seniors_frendly_element.text.strip())
        else:
            senior_frendly_list.append('N/A')
    else:
        senior_frendly_list.append('N/A')

    # Students only
    students_only_element = soup.find('span', class_='css-arxwps', text='Kun for studerende')

    if students_only_element:
        # Extract the corresponding value
        students_only_element = students_only_element.find_next('span', class_='css-1h46kg2')

        if students_only_element:
            # Extract the text content and add it to the list
            only_for_students_list.append(students_only_element.text.strip())
        else:
            only_for_students_list.append('N/A')
    else:
        only_for_students_list.append('N/A')

        
    # Balcony or terrace
    balcony_element = soup.find('span', class_='css-arxwps', text='Altan/terrasse')

    if balcony_element:
        # Extract the corresponding value
        balcony_element = balcony_element.find_next('span', class_='css-1h46kg2')

        if balcony_element:
            # Extract the text content and add it to the list
            balcony_or_terrace_list.append(balcony_element.text.strip())
        else:
            balcony_or_terrace_list.append('N/A')
    else:
        balcony_or_terrace_list.append('N/A')

    # Parking
    parking_element = soup.find('span', class_='css-arxwps', text='Parkering')

    if parking_element:
        # Extract the corresponding value
        parking_element = parking_element.find_next('span', class_='css-1h46kg2')

        if parking_element:
            # Extract the text content and add it to the list
            parking_list.append(parking_element.text.strip())
        else:
            parking_list.append('N/A')
    else:
        parking_list.append('N/A')

    # Energy label
    # Find: <img src="/static/images/energy_labels/C_str2.png" class="css-rdsunt">
    # Get "C_str2" from the src attribute
    energy_label_element = soup.find('span', class_='css-arxwps', text='Energimærke')
    energy_label_list1 = []

    if energy_label_element:
        # Extract the corresponding value
        energy_label_element = energy_label_element.find_next('img', class_='css-rdsunt')

        if energy_label_element:
            # Extract the text content and add it to the list
            energy_label_list1.append(energy_label_element['src'].split('/')[-1].split('_')[0])
            # Get the first letter of C_str2
            energy_label_list.append(energy_label_list1[0][0])

        else:
            energy_label_list.append('N/A')
    else:
        energy_label_list.append('N/A')

    # Find the div with class "css-1f7mpex" for the description
    description_element = soup.find('div', class_='css-1f7mpex')

    # Initialize an empty string to store the description
    description_text = ""

    # Check if the description element is found
    if description_element:
        # Extract the text content of the description
        description_text = description_element.get_text(separator=' ', strip=True)

    # If description_text is empty, set it to "N/A"
    if not description_text:
        description_text = "N/A"

    # Add the description text to the list
    description_list.append(description_text)

    # Append data to the current chunk
    current_chunk.append({
        'Adress': adress_list[i],
        'Monthly rent': monthly_rent_list[i],
        'Aconto': aconto_list[i],
        'Square meters': sqm_list[i],
        'Rooms': nr_rooms_list[i],
        'Floor': floor_list[i],
        'Property type': property_type_list[i],
        'Furnished': furnished_list[i],
        'Shareable': shareable_list[i],
        'Pets allowed': pets_allowed_list[i],
        'Elevator': elevator_list[i],
        'Senior frendly': senior_frendly_list[i],
        'Only for students': only_for_students_list[i],
        'Balcony/Terrace': balcony_or_terrace_list[i],
        'Parking': parking_list[i],
        'Energy label': energy_label_list[i],
        'Description': description_list[i],
        'Link': final_urls[i]
    })

    # Increment the counter
    scraped_count += 1

    # Check if 100 URLs have been scraped or if it's the last iteration, and save the dataframe
    if scraped_count % 100 == 0 or i == len(final_urls) - 1:
        chunk_number = (scraped_count - 1) // 100 + 1  # Update chunk number calculation
        
        # Check if it's the last iteration and adjust the data for the current chunk accordingly
        if i == len(final_urls) - 1:
            current_chunk = current_chunk[:scraped_count % 100 if scraped_count % 100 != 0 else 100]
        
        df_chunk = pd.DataFrame(current_chunk)

        # Save the dataframe
        df_chunk.to_csv(f'data_chunk_{chunk_number}.csv', index=False)

        # Clear the current chunk for the next iteration
        current_chunk = []

    # Pause for a short time before scraping the next page
    time.sleep(0.5)

# Concatenate and save the final DataFrame
all_chunks = []
num_chunks = (scraped_count // 100) + (1 if scraped_count % 100 != 0 else 0)

for chunk_number in range(1, num_chunks + 1):
    chunk_filename = f'data_chunk_{chunk_number}.csv'
    chunk_df = pd.read_csv(chunk_filename)
    all_chunks.append(chunk_df)

# Concatenate all chunks
final_df = pd.concat(all_chunks, ignore_index=True)

# Save the final dataframe
final_df.to_csv('final_data.csv', index=False)
# Out:
# Scraping Data: 100%|██████████| 360/360 [05:45<00:00,  1.04it/s]

# %%
# Load the saved CSV file and display its contents
boligportalen_df = pd.read_csv('final_data.csv')

# Count the initial number of rows
initial_row_count = len(boligportalen_df)

# Remove the duplicated links from the dataframe
boligportalen_df = boligportalen_df.drop_duplicates(subset=['Link'])

# Count the final number of rows after removing duplicates
final_row_count = len(boligportalen_df)

# Calculate the number of duplicates removed
duplicates_removed = initial_row_count - final_row_count

# Save boligportalen_df as a csv file
boligportalen_df.to_csv('boligportalen_df.csv', index=False)

# Check if there are any duplicates in the 'Link' column
duplicates_exist = boligportalen_df['Link'].duplicated().any()

# Print the result as a True or False statement
print("Duplicates exist in the 'Link' column:", duplicates_exist)

# Print the number of duplicates removed
print("Number of duplicates removed:", duplicates_removed)

boligportalen_df.head(1000)
# Out:
# Duplicates exist in the 'Link' column: False
# Number of duplicates removed: 58
#                                                Adress Monthly rent     Aconto  \
# 0          Fyensgade, 9000 Aalborg, Aalborg  - 4. sal    5.795 kr.    900 kr.
# 1       Hasserisgade, 9000 Aalborg, Aalborg  - 3. sal    5.795 kr.    900 kr.
# 2          Perikumvej, 9000 Aalborg, Aalborg  - Stuen    5.800 kr.    700 kr.
# 3                    Harpevej, 2730 København, Herlev    8.500 kr.  1.000 kr.
# 4    Vævergade, 2200 København, København N  - 4. sal   10.500 kr.  1.000 kr.
# ..                                                ...          ...        ...
# 352             Ørskovvænget, 7400 Herning, Snejbjerg    8.600 kr.      0 kr.
# 353                           Smedegade, 8752 Østbirk    5.343 kr.        NaN
# 354                    Sofienlundparken, 8860 Ulstrup    7.244 kr.    955 kr.
# 355                     Slotsvej, 6510 Gram  - 1. sal    2.623 kr.  1.338 kr.
# 356                 Gartnervænget, 6510 Gram  - Stuen    2.940 kr.  2.460 kr.
#
#     Square meters  Rooms  Floor Property type Furnished Shareable  \
# 0           60 m²      2     4.     Lejlighed       Nej       Nej
# 1           64 m²      2     3.     Lejlighed       Nej       Nej
# 2           66 m²      2  Stuen     Lejlighed       Nej       Nej
# 3           50 m²      2      -     Lejlighed       Nej       Nej
# 4           79 m²      3     4.     Lejlighed       Nej       Nej
# ..            ...    ...    ...           ...       ...       ...
# 352         95 m²      4      -      Rækkehus       Nej       Nej
# 353         70 m²      2      -      Rækkehus       Nej        Ja
# 354         90 m²      4      -      Rækkehus       Nej        Ja
# 355         44 m²      1     1.      Rækkehus       Nej       Nej
# 356         60 m²      2  Stuen      Rækkehus       Nej        Ja
#
#     Pets allowed Elevator Senior frendly Only for students Balcony/Terrace  \
# 0            Nej      Nej            Nej               Nej              Ja
# 1            Nej      Nej            Nej               Nej             Nej
# 2            Nej      Nej            Nej               Nej              Ja
# 3            Nej      Nej            Nej               Nej             Nej
# 4            Nej      Nej            Nej               Nej             Nej
# ..           ...      ...            ...               ...             ...
# 352          Nej      Nej            Nej               Nej             Nej
# 353           Ja      Nej            Nej               Nej             Nej
# 354           Ja      Nej            Nej                Ja             Nej
# 355          Nej      Nej            Nej               Nej             Nej
# 356           Ja      Nej            Nej               Nej             Nej
#
#     Parking Energy label                                        Description  \
# 0       Nej          NaN  Når man træder ind i denne fine lejlighed, kom...
# 1       Nej          NaN  Boligen er rummelig og har en fin plantegning,...
# 2       Nej          NaN  Lækker lejlighed i børnevenlig kvarter. Nymale...
# 3       Nej          NaN  Recently painted apartment\n\n1 bedroom (i.e 2...
# 4       Nej            C  OBS! Vi tager kun henvendelser seriøst, hvoraf...
# ..      ...          ...                                                ...
# 352     Nej          NaN  95 m2 4 vær. Bygget i 2017. Bestående af entre...
# 353     Nej          NaN  Flyt i hyggelige rækkehuse i Østbirk med egen ...
# 354     Nej          NaN  Afdelingens bebyggelser er opført i to afsnit ...
# 355     Nej          NaN  Afdelingen består af i alt 9 bebyggelser, plac...
# 356     Nej          NaN  Afdelingen består af i alt 9 bebyggelser, plac...
#
#                                                   Link
# 0    https://www.boligportal.dk/lejligheder/aalborg...
# 1    https://www.boligportal.dk/lejligheder/aalborg...
# 2    https://www.boligportal.dk/lejligheder/aalborg...
# 3    https://www.boligportal.dk/lejligheder/k%C3%B8...
# 4    https://www.boligportal.dk/lejligheder/k%C3%B8...
# ..                                                 ...
# 352  https://www.boligportal.dk/r%C3%A6kkehuse/hern...
# 353  https://www.boligportal.dk/r%C3%A6kkehuse/%C3%...
# 354  https://www.boligportal.dk/r%C3%A6kkehuse/ulst...
# 355  https://www.boligportal.dk/r%C3%A6kkehuse/gram...
# 356  https://www.boligportal.dk/r%C3%A6kkehuse/gram...
#
# [302 rows x 18 columns]
