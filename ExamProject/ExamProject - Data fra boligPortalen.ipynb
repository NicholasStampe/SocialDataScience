# %% [markdown]
# # Exam Project - Scraping BoligPortalen

# %%
# Import packages:
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import tqdm
import time

# Import packages:
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm  # Import tqdm for the progress bar

# Define function to get the data from the website: BoligPortal 
def scrape_data(offset):
    # Define the base URL:
    base_url = 'https://www.boligportal.dk/lejeboliger/?min_rental_period=0&offset={}'

    # Create the complete URL with the given offset:
    url = base_url.format(offset)

    # Connect to site:
    response = requests.get(url, headers={'name':'Jesper Højberg Knudsen','email':'fmw786@econ.ku.dk'})

    # Parse data with BeautifulSoup:
    soup = BeautifulSoup(response.content, 'lxml')

    # Find links to the individual ads:
    links = soup.find_all('a', class_='AdCardSrp__Link css-17x8ssx')

    # Make a list of URLs:
    url_list = [link['href'] for link in links]

    return url_list

# Set the initial offset and the step size:
initial_offset = 0
step_size = 18

# Define the number of iterations you want to perform:
num_iterations = 10  # You can change this as needed

# Create an empty list to store all URLs:
all_urls = []

# Loop through the desired number of iterations:
for i in tqdm(range(num_iterations), desc="Scraping URLs"):  # Use tqdm for progress bar
    offset = initial_offset + (i * step_size)
    urls = scrape_data(offset)
    all_urls.extend(urls)

# Make final list of working URLs:
final_urls = []

for url in all_urls:
    temp_url = 'https://www.boligportal.dk' + url
    final_urls.append(temp_url)

# Print all final scraped URLs:
for url in final_urls:
    print(url)
# Out:
# Scraping URLs: 100%|██████████| 10/10 [00:29<00:00,  2.99s/it]
# https://www.boligportal.dk/lejligheder/aalborg/102m2-4-vaer-id-5378405
# https://www.boligportal.dk/lejligheder/n%C3%A6stved/63m2-2-vaer-id-5150925
# https://www.boligportal.dk/huse/bredsten/114m2-4-vaer-id-5378377
# https://www.boligportal.dk/lejligheder/stubbek%C3%B8bing/66m2-2-vaer-id-5314357
# https://www.boligportal.dk/lejligheder/aalborg/60m2-2-vaer-id-5378335
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/100m2-4-vaer-id-5334883
# https://www.boligportal.dk/lejligheder/aalborg/65m2-2-vaer-id-5378340
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/99m2-4-vaer-id-5378402
# https://www.boligportal.dk/lejligheder/hj%C3%B8rring/35m2-1-vaer-id-5378349
# https://www.boligportal.dk/lejligheder/aalborg/77m2-3-vaer-id-5378332
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/102m2-4-vaer-id-5359564
# https://www.boligportal.dk/r%C3%A6kkehuse/bryrup/101m2-5-vaer-id-5378400
# https://www.boligportal.dk/lejligheder/horsens/48m2-2-vaer-id-5378381
# https://www.boligportal.dk/lejligheder/aalborg/90m2-3-vaer-id-5378399
# https://www.boligportal.dk/lejligheder/ribe/104m2-3-vaer-id-5378368
# https://www.boligportal.dk/lejligheder/aalborg/82m2-3-vaer-id-5378398
# https://www.boligportal.dk/lejligheder/odense/69m2-3-vaer-id-5378397
# https://www.boligportal.dk/lejligheder/odense/69m2-3-vaer-id-5378396
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/102m2-4-vaer-id-5359564
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/54m2-2-vaer-id-5378382
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/81m2-2-vaer-id-5364866
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/118m2-4-vaer-id-5364861
# https://www.boligportal.dk/lejligheder/odense/74m2-2-vaer-id-5358132
# https://www.boligportal.dk/lejligheder/odense/65m2-2-vaer-id-5377972
# https://www.boligportal.dk/lejligheder/odense/91m2-4-vaer-id-5378395
# https://www.boligportal.dk/lejligheder/odense/69m2-3-vaer-id-5378394
# https://www.boligportal.dk/lejligheder/odense/69m2-3-vaer-id-5378393
# https://www.boligportal.dk/lejligheder/odense/69m2-3-vaer-id-5378392
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/149m2-5-vaer-id-5378391
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/64m2-2-vaer-id-5378390
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/64m2-2-vaer-id-5294190
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/67m2-2-vaer-id-5378389
# https://www.boligportal.dk/lejligheder/aalborg/79m2-3-vaer-id-5377865
# https://www.boligportal.dk/r%C3%A6kkehuse/k%C3%B8benhavn/117m2-4-vaer-id-5300354
# https://www.boligportal.dk/lejligheder/aarhus/57m2-2-vaer-id-5234275
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/64m2-2-vaer-id-5378388
# https://www.boligportal.dk/r%C3%A6kkehuse/k%C3%B8benhavn/109m2-4-vaer-id-5185164
# https://www.boligportal.dk/r%C3%A6kkehuse/k%C3%B8benhavn/131m2-5-vaer-id-5226226
# https://www.boligportal.dk/lejligheder/aarhus/77m2-2-vaer-id-5378387
# https://www.boligportal.dk/lejligheder/aarhus/86m2-3-vaer-id-5378386
# https://www.boligportal.dk/lejligheder/aarhus/90m2-3-vaer-id-5285092
# https://www.boligportal.dk/lejligheder/varde/46m2-1-vaer-id-5378339
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/102m2-4-vaer-id-5359564
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/54m2-2-vaer-id-5378382
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/81m2-2-vaer-id-5364866
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/118m2-4-vaer-id-5364861
# https://www.boligportal.dk/lejligheder/odense/74m2-2-vaer-id-5358132
# https://www.boligportal.dk/lejligheder/odense/65m2-2-vaer-id-5377972
# https://www.boligportal.dk/lejligheder/kolding/48m2-2-vaer-id-5378385
# https://www.boligportal.dk/v%C3%A6relser/aarhus/20m2-1-vaer-id-5378084
# https://www.boligportal.dk/v%C3%A6relser/aarhus/14m2-1-vaer-id-5378101
# https://www.boligportal.dk/lejligheder/aarhus/40m2-1-vaer-id-5172879
# https://www.boligportal.dk/v%C3%A6relser/k%C3%B8benhavn/23m2-1-vaer-id-4862503
# https://www.boligportal.dk/lejligheder/aalborg/114m2-3-vaer-id-5378384
# https://www.boligportal.dk/lejligheder/slagelse/57m2-2-vaer-id-5378383
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/54m2-2-vaer-id-5378382
# https://www.boligportal.dk/huse/esbjerg/150m2-5-vaer-id-2946504
# https://www.boligportal.dk/lejligheder/nibe/61m2-2-vaer-id-5378380
# https://www.boligportal.dk/lejligheder/aarhus/68m2-3-vaer-id-3013760
# https://www.boligportal.dk/v%C3%A6relser/aarhus/13m2-1-vaer-id-4904160
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/90m2-3-vaer-id-5294087
# https://www.boligportal.dk/lejligheder/frederikshavn/65m2-2-vaer-id-5033300
# https://www.boligportal.dk/lejligheder/aalborg/70m2-2-vaer-id-5328680
# https://www.boligportal.dk/lejligheder/aalborg/55m2-2-vaer-id-4626367
# https://www.boligportal.dk/lejligheder/videb%C3%A6k/70m2-2-vaer-id-3837007
# https://www.boligportal.dk/lejligheder/svendborg/73m2-3-vaer-id-1737914
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/102m2-4-vaer-id-5359564
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/54m2-2-vaer-id-5378382
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/81m2-2-vaer-id-5364866
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/118m2-4-vaer-id-5364861
# https://www.boligportal.dk/lejligheder/odense/74m2-2-vaer-id-5358132
# https://www.boligportal.dk/lejligheder/odense/65m2-2-vaer-id-5377972
# https://www.boligportal.dk/lejligheder/svendborg/73m2-3-vaer-id-1737914
# https://www.boligportal.dk/lejligheder/aalborg/132m2-4-vaer-id-3707968
# https://www.boligportal.dk/lejligheder/aarhus/54m2-2-vaer-id-5378379
# https://www.boligportal.dk/lejligheder/aarhus/30m2-1-vaer-id-5283482
# https://www.boligportal.dk/r%C3%A6kkehuse/ans-by/114m2-3-vaer-id-5354958
# https://www.boligportal.dk/lejligheder/aalborg/60m2-2-vaer-id-5378378
# https://www.boligportal.dk/lejligheder/ans-by/81m2-3-vaer-id-5313339
# https://www.boligportal.dk/huse/skjern/120m2-4-vaer-id-5378165
# https://www.boligportal.dk/lejligheder/vejle/70m2-2-vaer-id-5356100
# https://www.boligportal.dk/lejligheder/kolding/111m2-3-vaer-id-5378333
# https://www.boligportal.dk/lejligheder/aalborg/101m2-4-vaer-id-5378375
# https://www.boligportal.dk/lejligheder/aalborg/64m2-2-vaer-id-5378374
# https://www.boligportal.dk/lejligheder/kolding/116m2-4-vaer-id-4957417
# https://www.boligportal.dk/huse/aabybro/79m2-3-vaer-id-5378369
# https://www.boligportal.dk/lejligheder/hj%C3%B8rring/50m2-2-vaer-id-5160895
# https://www.boligportal.dk/lejligheder/aarhus/32m2-1-vaer-id-4572552
# https://www.boligportal.dk/lejligheder/aarhus/79m2-3-vaer-id-5378367
# https://www.boligportal.dk/r%C3%A6kkehuse/hedensted/98m2-3-vaer-id-5350159
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/102m2-4-vaer-id-5359564
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/54m2-2-vaer-id-5378382
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/81m2-2-vaer-id-5364866
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/118m2-4-vaer-id-5364861
# https://www.boligportal.dk/lejligheder/odense/74m2-2-vaer-id-5358132
# https://www.boligportal.dk/lejligheder/odense/65m2-2-vaer-id-5377972
# https://www.boligportal.dk/r%C3%A6kkehuse/hedensted/98m2-3-vaer-id-5350159
# https://www.boligportal.dk/lejligheder/aalborg/92m2-2-vaer-id-3210419
# https://www.boligportal.dk/lejligheder/thisted/63m2-2-vaer-id-5255117
# https://www.boligportal.dk/lejligheder/thisted/85m2-3-vaer-id-5378364
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/87m2-4-vaer-id-5289340
# https://www.boligportal.dk/lejligheder/aarhus/57m2-2-vaer-id-5346378
# https://www.boligportal.dk/lejligheder/aalborg/63m2-2-vaer-id-3488797
# https://www.boligportal.dk/r%C3%A6kkehuse/odense/120m2-5-vaer-id-5378363
# https://www.boligportal.dk/r%C3%A6kkehuse/odense/120m2-5-vaer-id-5378362
# https://www.boligportal.dk/v%C3%A6relser/aarhus/15m2-1-vaer-id-5378126
# https://www.boligportal.dk/lejligheder/stege/38m2-1-vaer-id-4282723
# https://www.boligportal.dk/lejligheder/aarhus/64m2-2-vaer-id-5064519
# https://www.boligportal.dk/lejligheder/randers/50m2-2-vaer-id-5378361
# https://www.boligportal.dk/lejligheder/aabenraa/35m2-1-vaer-id-4335859
# https://www.boligportal.dk/r%C3%A6kkehuse/hj%C3%B8rring/86m2-4-vaer-id-5378109
# https://www.boligportal.dk/lejligheder/svendborg/53m2-2-vaer-id-5322758
# https://www.boligportal.dk/r%C3%A6kkehuse/k%C3%B8benhavn/130m2-5-vaer-id-5378360
# https://www.boligportal.dk/lejligheder/aarhus/69m2-2-vaer-id-5378358
# https://www.boligportal.dk/lejligheder/horsens/72m2-2-vaer-id-5255652
# https://www.boligportal.dk/r%C3%A6kkehuse/horsens/100m2-4-vaer-id-5368099
# https://www.boligportal.dk/lejligheder/odense/74m2-2-vaer-id-5358132
# https://www.boligportal.dk/lejligheder/odense/65m2-2-vaer-id-5377972
# https://www.boligportal.dk/lejligheder/nyk%C3%B8bing-m/51m2-2-vaer-id-5339392
# https://www.boligportal.dk/lejligheder/horsens/111m2-2-vaer-id-5292236
# https://www.boligportal.dk/lejligheder/klarup/88m2-2-vaer-id-5325569
# https://www.boligportal.dk/lejligheder/aarhus/99m2-2-vaer-id-5110272
# https://www.boligportal.dk/lejligheder/aabenraa/90m2-4-vaer-id-2992474
# https://www.boligportal.dk/lejligheder/aalborg/58m2-2-vaer-id-5378354
# https://www.boligportal.dk/lejligheder/slagelse/60m2-3-vaer-id-5000466
# https://www.boligportal.dk/lejligheder/silkeborg/99m2-3-vaer-id-5378353
# https://www.boligportal.dk/r%C3%A6kkehuse/silkeborg/114m2-4-vaer-id-5378352
# https://www.boligportal.dk/r%C3%A6kkehuse/silkeborg/101m2-3-vaer-id-5378351
# https://www.boligportal.dk/lejligheder/silkeborg/99m2-3-vaer-id-5378350
# https://www.boligportal.dk/huse/middelfart/140m2-4-vaer-id-5378188
# https://www.boligportal.dk/huse/kolding/170m2-7-vaer-id-4981295
# https://www.boligportal.dk/lejligheder/aalborg/60m2-2-vaer-id-5230718
# https://www.boligportal.dk/lejligheder/horsens/97m2-3-vaer-id-5317646
# https://www.boligportal.dk/lejligheder/marstal/147m2-5-vaer-id-4337270
# https://www.boligportal.dk/r%C3%A6kkehuse/silkeborg/97m2-3-vaer-id-5347000
# https://www.boligportal.dk/lejligheder/aabenraa/86m2-3-vaer-id-4602914
# https://www.boligportal.dk/lejligheder/aabenraa/98m2-3-vaer-id-4710379
# https://www.boligportal.dk/lejligheder/fjerritslev/85m2-3-vaer-id-5325286
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/102m2-4-vaer-id-5359564
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/54m2-2-vaer-id-5378382
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/81m2-2-vaer-id-5364866
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/118m2-4-vaer-id-5364861
# https://www.boligportal.dk/lejligheder/odense/74m2-2-vaer-id-5358132
# https://www.boligportal.dk/lejligheder/odense/65m2-2-vaer-id-5377972
# https://www.boligportal.dk/lejligheder/sk%C3%A5rup-fyn/23m2-1-vaer-id-5378347
# https://www.boligportal.dk/lejligheder/skive/97m2-3-vaer-id-5250465
# https://www.boligportal.dk/lejligheder/ribe/80m2-3-vaer-id-3625928
# https://www.boligportal.dk/lejligheder/t%C3%B8nder/32m2-1-vaer-id-5378334
# https://www.boligportal.dk/lejligheder/aarhus/100m2-3-vaer-id-2969023
# https://www.boligportal.dk/lejligheder/t%C3%B8nder/32m2-1-vaer-id-5378331
# https://www.boligportal.dk/lejligheder/t%C3%B8nder/32m2-1-vaer-id-5378337
# https://www.boligportal.dk/lejligheder/horsens/71m2-2-vaer-id-5378345
# https://www.boligportal.dk/lejligheder/horsens/71m2-2-vaer-id-5378344
# https://www.boligportal.dk/lejligheder/horsens/75m2-2-vaer-id-5378343
# https://www.boligportal.dk/lejligheder/horsens/71m2-2-vaer-id-5378342
# https://www.boligportal.dk/lejligheder/horsens/75m2-2-vaer-id-5378341
# https://www.boligportal.dk/lejligheder/odense/66m2-2-vaer-id-5378338
# https://www.boligportal.dk/lejligheder/aarhus/110m2-3-vaer-id-4904798
# https://www.boligportal.dk/lejligheder/aarhus/41m2-1-vaer-id-4626058
# https://www.boligportal.dk/huse/ulstrup/99m2-3-vaer-id-5378250
# https://www.boligportal.dk/r%C3%A6kkehuse/k%C3%B8ge/120m2-4-vaer-id-5369216
# https://www.boligportal.dk/lejligheder/vissenbjerg/107m2-4-vaer-id-5378234
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/102m2-4-vaer-id-5359564
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/54m2-2-vaer-id-5378382
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/81m2-2-vaer-id-5364866
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/118m2-4-vaer-id-5364861
# https://www.boligportal.dk/lejligheder/odense/74m2-2-vaer-id-5358132
# https://www.boligportal.dk/lejligheder/odense/65m2-2-vaer-id-5377972
# https://www.boligportal.dk/lejligheder/holstebro/65m2-2-vaer-id-5378330
# https://www.boligportal.dk/lejligheder/silkeborg/130m2-3-vaer-id-5378325
# https://www.boligportal.dk/r%C3%A6kkehuse/herning/95m2-4-vaer-id-5259330
# https://www.boligportal.dk/r%C3%A6kkehuse/%C3%B8stbirk/70m2-2-vaer-id-5318988
# https://www.boligportal.dk/r%C3%A6kkehuse/ulstrup/90m2-4-vaer-id-5378329
# https://www.boligportal.dk/r%C3%A6kkehuse/gram/44m2-1-vaer-id-5378328
# https://www.boligportal.dk/r%C3%A6kkehuse/gram/60m2-2-vaer-id-5271041
# https://www.boligportal.dk/lejligheder/aarhus/31m2-1-vaer-id-5378228
# https://www.boligportal.dk/lejligheder/horsens/80m2-4-vaer-id-4914374
# https://www.boligportal.dk/huse/silkeborg/185m2-6-vaer-id-5378230
# https://www.boligportal.dk/lejligheder/holstebro/76m2-3-vaer-id-2623582
# https://www.boligportal.dk/r%C3%A6kkehuse/viborg/100m2-4-vaer-id-5365897
# https://www.boligportal.dk/huse/br%C3%B8nderslev/65m2-2-vaer-id-5378218
# https://www.boligportal.dk/lejligheder/randers/51m2-2-vaer-id-4230428
# https://www.boligportal.dk/lejligheder/aalborg/104m2-3-vaer-id-5134115
# https://www.boligportal.dk/lejligheder/vejle/77m2-2-vaer-id-4452798
# https://www.boligportal.dk/lejligheder/odense/118m2-4-vaer-id-5378326
# https://www.boligportal.dk/lejligheder/odense/77m2-3-vaer-id-5378030
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/102m2-4-vaer-id-5359564
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/54m2-2-vaer-id-5378382
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/81m2-2-vaer-id-5364866
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/118m2-4-vaer-id-5364861
# https://www.boligportal.dk/lejligheder/odense/74m2-2-vaer-id-5358132
# https://www.boligportal.dk/lejligheder/odense/65m2-2-vaer-id-5377972
# https://www.boligportal.dk/lejligheder/horsens/72m2-2-vaer-id-5255652
# https://www.boligportal.dk/lejligheder/aarhus/32m2-1-vaer-id-3486205
# https://www.boligportal.dk/lejligheder/odense/93m2-3-vaer-id-5378324
# https://www.boligportal.dk/lejligheder/aabenraa/70m2-2-vaer-id-5378323
# https://www.boligportal.dk/lejligheder/aarhus/83m2-4-vaer-id-5178028
# https://www.boligportal.dk/lejligheder/toftlund/74m2-2-vaer-id-3759193
# https://www.boligportal.dk/huse/nakskov/53m2-2-vaer-id-4920831
# https://www.boligportal.dk/r%C3%A6kkehuse/odense/96m2-3-vaer-id-5378321
# https://www.boligportal.dk/lejligheder/aarhus/62m2-3-vaer-id-5378320
# https://www.boligportal.dk/lejligheder/saksk%C3%B8bing/36m2-1-vaer-id-5378271
# https://www.boligportal.dk/huse/h%C3%B8jer/93m2-5-vaer-id-4111480
# https://www.boligportal.dk/lejligheder/odense/63m2-2-vaer-id-3546460
# https://www.boligportal.dk/lejligheder/br%C3%A6dstrup/116m2-4-vaer-id-5283116
# https://www.boligportal.dk/lejligheder/frederikssund/58m2-2-vaer-id-5378319
# https://www.boligportal.dk/r%C3%A6kkehuse/asaa/76m2-3-vaer-id-5378294
# https://www.boligportal.dk/lejligheder/horsens/100m2-3-vaer-id-4633756
# https://www.boligportal.dk/lejligheder/haslev/70m2-3-vaer-id-5245471
# https://www.boligportal.dk/lejligheder/aalborg/113m2-4-vaer-id-3525412
# https://www.boligportal.dk/lejligheder/horsens/72m2-2-vaer-id-5255652
# https://www.boligportal.dk/r%C3%A6kkehuse/horsens/100m2-4-vaer-id-5368099
# https://www.boligportal.dk/lejligheder/odense/74m2-2-vaer-id-5358132
# https://www.boligportal.dk/lejligheder/odense/65m2-2-vaer-id-5377972
# https://www.boligportal.dk/lejligheder/nyk%C3%B8bing-m/51m2-2-vaer-id-5339392
# https://www.boligportal.dk/lejligheder/horsens/111m2-2-vaer-id-5292236
# https://www.boligportal.dk/huse/hovborg/140m2-4-vaer-id-5372477
# https://www.boligportal.dk/lejligheder/aalborg/94m2-3-vaer-id-4391195
# https://www.boligportal.dk/lejligheder/vejen/100m2-3-vaer-id-3403669
# https://www.boligportal.dk/lejligheder/viborg/124m2-4-vaer-id-5378270
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/72m2-2-vaer-id-5261882
# https://www.boligportal.dk/lejligheder/aalborg/50m2-2-vaer-id-5378268
# https://www.boligportal.dk/lejligheder/aarhus/90m2-4-vaer-id-5286196
# https://www.boligportal.dk/lejligheder/skjern/81m2-2-vaer-id-5378296
# https://www.boligportal.dk/lejligheder/haderslev/119m2-4-vaer-id-5343408
# https://www.boligportal.dk/lejligheder/k%C3%B8benhavn/90m2-2-vaer-id-5378185
# https://www.boligportal.dk/v%C3%A6relser/aarhus/17m2-1-vaer-id-5313078
# https://www.boligportal.dk/lejligheder/vejle/60m2-2-vaer-id-5181653
# https://www.boligportal.dk/huse/tim/118m2-3-vaer-id-4654614
# https://www.boligportal.dk/huse/ebeltoft/175m2-5-vaer-id-5352486
# https://www.boligportal.dk/lejligheder/st%C3%B8vring/92m2-3-vaer-id-4515953
# https://www.boligportal.dk/lejligheder/herning/71m2-2-vaer-id-5091348
# https://www.boligportal.dk/lejligheder/vr%C3%A5/42m2-1-vaer-id-5315969
# https://www.boligportal.dk/lejligheder/ranum/65m2-3-vaer-id-4936746
# https://www.boligportal.dk/lejligheder/horsens/72m2-2-vaer-id-5255652
# https://www.boligportal.dk/r%C3%A6kkehuse/horsens/100m2-4-vaer-id-5368099
# https://www.boligportal.dk/lejligheder/odense/74m2-2-vaer-id-5358132
# https://www.boligportal.dk/lejligheder/odense/65m2-2-vaer-id-5377972
# https://www.boligportal.dk/lejligheder/nyk%C3%B8bing-m/51m2-2-vaer-id-5339392
# https://www.boligportal.dk/lejligheder/horsens/111m2-2-vaer-id-5292236

# %%
# List of information we want to scarpe:
adress_list = []
monthly_rent_list = []
aconto_list = []
sqm_list = []
nr_rooms_list = []
floor_list = []
property_type_list = []
furnished_list = []
shareable_list = []
pets_allowed_list = []
elevator_list = []
senior_frendly_list = []
only_for_students_list = []
balcony_or_terrace_list = []
parking_list = []
energy_label_list = []
description_list = []

# Initialize a counter to keep track of the number of scraped URLs
scraped_count = 0

# Loop through all the pages
for i in tqdm(range(len(final_urls)), desc="Scraping Data"):
    # Scraping
    url = final_urls[i]
    response = requests.get(url, headers={'name':'Jesper Højberg Knudsen','email':'fmw786@econ.ku.dk'})
    soup = BeautifulSoup(response.text, 'lxml')
    
    # Adress
    # Find the label "css-11fbmqw" within the section
    element = soup.find('span', class_='css-11fbmqw')
    if element:
        # Extract the corresponding value
        adress_element = element.find_next('div', class_='css-v49nss')

        if adress_element:
            # Extract the text content and add it to the list
            adress_list.append(adress_element.text.strip())
        else:
            adress_list.append('N/A') # Handle case if the value is not found

    else:
        adress_list.append('N/A') # Handle case if the label is not found


    # Monthly rent
    # Find the label "Månedlig leje" within the section
    label_element = soup.find('span', text='Månedlig leje', class_='css-arxwps')
    
    if label_element:
        # Extract the corresponding value
        monthly_rent_element = label_element.find_next('span', class_='css-1h46kg2')
        
        if monthly_rent_element:
            # Extract the text content and add it to the list
            monthly_rent_list.append(monthly_rent_element.text.strip())
        else:
            monthly_rent_list.append('N/A')  # Handle case if the value is not found
    else:
        monthly_rent_list.append('N/A')  # Handle case if the label is not found

    # Aconto
    # Find the label "Aconto" within the section
    aconto_element = soup.find('span', class_='css-arxwps', text='Aconto')

    if aconto_element:
        # Extract the corresponding value
        aconto_element = aconto_element.find_next('span', class_='css-1h46kg2')

        if aconto_element:
            # Extract the text content and add it to the list
            aconto_list.append(aconto_element.text.strip())
        else:
            aconto_list.append('N/A')
    else:
        aconto_list.append('N/A')
        
    # Square meters
    # Find the label "Størrelse" within the section
    square_element = soup.find('span', class_='css-arxwps', text='Størrelse')

    if square_element:
        # Extract the corresponding value
        square_element = square_element.find_next('span', class_='css-1h46kg2')

        if square_element:
            # Extract the text content and add it to the list
            sqm_list.append(square_element.text.strip())
        else:
            sqm_list.append('N/A')
    else:
        sqm_list.append('N/A')


    # Number of rooms
    # Find the label "Værelser" within the section
    nr_rooms_element = soup.find('span', class_='css-arxwps', text='Værelser')

    if nr_rooms_element:
        # Extract the corresponding value
        nr_rooms_element = nr_rooms_element.find_next('span', class_='css-1h46kg2')

        if nr_rooms_element:
            # Extract the text content and add it to the list
            nr_rooms_list.append(nr_rooms_element.text.strip())
        else:
            nr_rooms_list.append('N/A')
    else:
        nr_rooms_list.append('N/A')
    
    # Floor
    # Find the label "Etage" within the section
    floor_element = soup.find('span', class_='css-arxwps', text='Etage')

    if floor_element:
        # Extract the corresponding value
        floor_element = floor_element.find_next('span', class_='css-1h46kg2')

        if floor_element:
            # Extract the text content and add it to the list
            floor_list.append(floor_element.text.strip())
        else:
            floor_list.append('N/A')
    else:
        floor_list.append('N/A')

    # Property type
    # Find the label "Boligtype" within the section
    property_type_element = soup.find('span', class_='css-arxwps', text='Boligtype')
    if property_type_element:
        # Extract the corresponding value
        property_type = property_type_element.find_next('span', class_='css-1h46kg2')
        if property_type:
            # Extract the text content and add it to the list
            property_type_list.append(property_type.text.strip())
        else:
            property_type_list.append('N/A')
    else:
        property_type_list.append('N/A')

    # Furnished
    # Find the label "Møbleret" within the section
    furnished_element = soup.find('span', class_='css-arxwps', text='Møbleret')

    if furnished_element:
        # Extract the corresponding value
        furnished_element = furnished_element.find_next('span', class_='css-1h46kg2')

        if furnished_element:
            # Extract the text content and add it to the list
            furnished_list.append(furnished_element.text.strip())
        else:
            furnished_list.append('N/A')
    else:
        furnished_list.append('N/A')

    # Shareable
    # Find the label "Delevenlig" within the section
    shareable_element = soup.find('span', class_='css-arxwps', text='Delevenlig')

    if shareable_element:
        # Extract the corresponding value
        shareable_element = shareable_element.find_next('span', class_='css-1h46kg2')

        if shareable_element:
            # Extract the text content and add it to the list
            shareable_list.append(shareable_element.text.strip())
        else:
            shareable_list.append('N/A')
    else:
        shareable_list.append('N/A')

    # Pets allowed
    # Find the label "Husdyr tilladt" within the section
    pets_allowed_element = soup.find('span', class_='css-arxwps', text='Husdyr tilladt')

    if pets_allowed_element:
        # Extract the corresponding value
        pets_allowed_element = pets_allowed_element.find_next('span', class_='css-1h46kg2')

        if pets_allowed_element:
            # Extract the text content and add it to the list
            pets_allowed_list.append(pets_allowed_element.text.strip())
        else:
            pets_allowed_list.append('N/A')
    else:
        pets_allowed_list.append('N/A')

    # elevator
    # Find the label "Elevator" within the section
    elevator_element = soup.find('span', class_='css-arxwps', text='Elevator')

    if elevator_element:
        # Extract the corresponding value
        elevator_element = elevator_element.find_next('span', class_='css-1h46kg2')

        if elevator_element:
            # Extract the text content and add it to the list
            elevator_list.append(elevator_element.text.strip())
        else:
            elevator_list.append('N/A')
    else:
        elevator_list.append('N/A')

    # Seniors frendly
    # Find the label "Seniorvenlig" within the section
    seniors_frendly_element = soup.find('span', class_='css-arxwps', text='Seniorvenlig')

    if seniors_frendly_element:
        # Extract the corresponding value
        seniors_frendly_element = seniors_frendly_element.find_next('span', class_='css-1h46kg2')

        if seniors_frendly_element:
            # Extract the text content and add it to the list
            senior_frendly_list.append(seniors_frendly_element.text.strip())
        else:
            senior_frendly_list.append('N/A')
    else:
        senior_frendly_list.append('N/A')

    # Students only
    students_only_element = soup.find('span', class_='css-arxwps', text='Kun for studerende')

    if students_only_element:
        # Extract the corresponding value
        students_only_element = students_only_element.find_next('span', class_='css-1h46kg2')

        if students_only_element:
            # Extract the text content and add it to the list
            only_for_students_list.append(students_only_element.text.strip())
        else:
            only_for_students_list.append('N/A')
    else:
        only_for_students_list.append('N/A')

        
    # Balcony or terrace
    balcony_element = soup.find('span', class_='css-arxwps', text='Altan/terrasse')

    if balcony_element:
        # Extract the corresponding value
        balcony_element = balcony_element.find_next('span', class_='css-1h46kg2')

        if balcony_element:
            # Extract the text content and add it to the list
            balcony_or_terrace_list.append(balcony_element.text.strip())
        else:
            balcony_or_terrace_list.append('N/A')
    else:
        balcony_or_terrace_list.append('N/A')

    # Parking
    parking_element = soup.find('span', class_='css-arxwps', text='Parkering')

    if parking_element:
        # Extract the corresponding value
        parking_element = parking_element.find_next('span', class_='css-1h46kg2')

        if parking_element:
            # Extract the text content and add it to the list
            parking_list.append(parking_element.text.strip())
        else:
            parking_list.append('N/A')
    else:
        parking_list.append('N/A')

    # Energy label
    # Find: <img src="/static/images/energy_labels/C_str2.png" class="css-rdsunt">
    # Get "C_str2" from the src attribute
    energy_label_element = soup.find('span', class_='css-arxwps', text='Energimærke')
    energy_label_list1 = []

    if energy_label_element:
        # Extract the corresponding value
        energy_label_element = energy_label_element.find_next('img', class_='css-rdsunt')

        if energy_label_element:
            # Extract the text content and add it to the list
            energy_label_list1.append(energy_label_element['src'].split('/')[-1].split('_')[0])
            # Get the first letter of C_str2
            energy_label_list.append(energy_label_list1[0][0])

        else:
            energy_label_list.append('N/A')
    else:
        energy_label_list.append('N/A')

    # Find the div with class "css-1f7mpex" for the description
    description_element = soup.find('div', class_='css-1f7mpex')

    # Initialize an empty string to store the description
    description_text = ""

    # Check if the description element is found
    if description_element:
        # Extract the text content of the description
        description_text = description_element.get_text(separator=' ', strip=True)

    # If description_text is empty, set it to "N/A"
    if not description_text:
        description_text = "N/A"

    # Add the description text to the list
    description_list.append(description_text)

    # Increment the counter
    scraped_count += 1

    # Check if 100 URLs have been scraped and save the dataframe
    if scraped_count % 100 == 0:
        chunk_number = scraped_count // 100
        df_chunk = pd.DataFrame({
            'Adress': adress_list,
            'Monthly rent': monthly_rent_list,
            'Aconto': aconto_list,
            'Square meters': sqm_list,
            'Rooms': nr_rooms_list,
            'Floor': floor_list,
            'Property type': property_type_list,
            'Furnished': furnished_list,
            'Shareable': shareable_list,
            'Pets allowed': pets_allowed_list,
            'Elevator': elevator_list,
            'Senior frendly': senior_frendly_list,
            'Only for students': only_for_students_list,
            'Balcony/Terrace': balcony_or_terrace_list,
            'Parking': parking_list,
            'Energy label': energy_label_list,
            'Description': description_list,
            'Link': final_urls[:scraped_count]  # Save only up to the current count
        })
        
        # Save the dataframe
        df_chunk.to_csv(f'data_chunk_{chunk_number}.csv', index=False)

    # Pause for a short time before scraping the next page
    time.sleep(0.5)

all_chunks = []
for chunk_number in range(1, (scraped_count // 100) + 1):
    chunk_filename = f'data_chunk_{chunk_number}.csv'
    chunk_df = pd.read_csv(chunk_filename)
    all_chunks.append(chunk_df)

# Concatenate all chunks
final_df = pd.concat(all_chunks, ignore_index=True)

# Add the remaining data to the final dataframe
remaining_data = {
    'Adress': adress_list,
    'Monthly rent': monthly_rent_list,
    'Aconto': aconto_list,
    'Square meters': sqm_list,
    'Rooms': nr_rooms_list,
    'Floor': floor_list,
    'Property type': property_type_list,
    'Furnished': furnished_list,
    'Shareable': shareable_list,
    'Pets allowed': pets_allowed_list,
    'Elevator': elevator_list,
    'Senior frendly': senior_frendly_list,
    'Only for students': only_for_students_list,
    'Balcony/Terrace': balcony_or_terrace_list,
    'Parking': parking_list,
    'Energy label': energy_label_list,
    'Description': description_list,
    'Link': final_urls[:scraped_count]
}
remaining_df = pd.DataFrame(remaining_data)

# Concatenate the remaining data to the final dataframe
final_df = pd.concat([final_df, remaining_df], ignore_index=True)

# Save the final dataframe
final_df.to_csv('final_data.csv', index=False)
# Out:
# Scraping Data: 100%|██████████| 240/240 [03:35<00:00,  1.11it/s]

# %%
# Display the first 120 rows of the dataframe
final_df.head(120)
# Out:
#                                                 Adress Monthly rent  \
# 0    Poul Anker Bechs Vej, 9200 Aalborg, Aalborg SV...    9.770 kr.
# 1                Kildemarksvej, 4700 Næstved  - 1. sal    6.065 kr.
# 2                            Vestervang, 7182 Bredsten    7.600 kr.
# 3         Møllegårds Alle, 4850 Stubbekøbing  - 1. sal    5.500 kr.
# 4           Fyensgade, 9000 Aalborg, Aalborg  - 4. sal    5.845 kr.
# ..                                                 ...          ...
# 115    Tornhøjvej, 9220 Aalborg, Aalborg Øst  - 2. sal    7.232 kr.
# 116               Miliegræsset, 5220 Odense, Odense SØ    7.800 kr.
# 117               Miliegræsset, 5220 Odense, Odense SØ    7.800 kr.
# 118   Elektronikvej, 2605 København, Brøndby  - 2. sal   13.800 kr.
# 119  Flaskehalsen, 1799 København, København V  - 5...   13.200 kr.
#
#         Aconto Square meters Rooms Floor Property type Furnished Shareable  \
# 0      700 kr.        102 m²     4    2.     Lejlighed       Nej       Nej
# 1    1.135 kr.         63 m²     2    1.     Lejlighed       Nej        Ja
# 2      350 kr.        114 m²     4     -           Hus       Nej       Nej
# 3      600 kr.         66 m²     2    1.     Lejlighed       Nej       Nej
# 4      900 kr.         60 m²     2    4.     Lejlighed       Nej       Nej
# ..         ...           ...   ...   ...           ...       ...       ...
# 115    425 kr.         82 m²     3    2.     Lejlighed       Nej       Nej
# 116        NaN         69 m²     3     -     Lejlighed       Nej       Nej
# 117        NaN         69 m²     3     -     Lejlighed       Nej       Nej
# 118  1.150 kr.        102 m²     4    2.     Lejlighed       Nej        Ja
# 119    800 kr.         54 m²     2    5.     Lejlighed       Nej       Nej
#
#     Pets allowed Elevator Senior frendly Only for students Balcony/Terrace  \
# 0             Ja       Ja             Ja               Nej              Ja
# 1            Nej      Nej            Nej               Nej             Nej
# 2             Ja      Nej            Nej               Nej              Ja
# 3            Nej      Nej            Nej               Nej             Nej
# 4            Nej      Nej            Nej               Nej              Ja
# ..           ...      ...            ...               ...             ...
# 115           Ja       Ja            Nej               Nej              Ja
# 116           Ja      Nej            Nej               Nej              Ja
# 117           Ja      Nej            Nej               Nej              Ja
# 118           Ja       Ja             Ja               Nej              Ja
# 119           Ja       Ja             Ja               Nej             Nej
#
#     Parking Energy label                                        Description  \
# 0        Ja          NaN  Hasserisparken ligger på det naturskønne Hasse...
# 1        Ja          NaN  Stor, lys 2 værelse lejlighed, bestående af en...
# 2        Ja            E  Huset indeholder en stor vinkelstue med pilleb...
# 3       Nej            D  Hyggelig ejendom med fire lejemål med fælles h...
# 4       Nej          NaN  Lejligheden byder velkommen med en indbydende ...
# ..      ...          ...                                                ...
# 115     Nej          NaN  De nye lejeboliger er med 1-, 2- eller 3-værel...
# 116      Ja          NaN  I attraktive Fraugde udlejes dette dejlige 2 p...
# 117      Ja          NaN  I attraktive Fraugde udlejes dette dejlige 2 p...
# 118      Ja            A  Flyt ind på Mekanikken - nybygget ejendom fra ...
# 119      Ja            A  Med denne 2 vær får du en lejlighed centralt p...
#
#                                                   Link
# 0    https://www.boligportal.dk/lejligheder/aalborg...
# 1    https://www.boligportal.dk/lejligheder/n%C3%A6...
# 2    https://www.boligportal.dk/huse/bredsten/114m2...
# 3    https://www.boligportal.dk/lejligheder/stubbek...
# 4    https://www.boligportal.dk/lejligheder/aalborg...
# ..                                                 ...
# 115  https://www.boligportal.dk/lejligheder/aalborg...
# 116  https://www.boligportal.dk/lejligheder/odense/...
# 117  https://www.boligportal.dk/lejligheder/odense/...
# 118  https://www.boligportal.dk/lejligheder/k%C3%B8...
# 119  https://www.boligportal.dk/lejligheder/k%C3%B8...
#
# [120 rows x 18 columns]
