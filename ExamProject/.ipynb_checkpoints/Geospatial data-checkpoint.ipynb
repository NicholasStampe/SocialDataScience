# %% [markdown]
# - Identify the Geospatial Attributes You Need: **shopping centre, schools, restaurants, public transportation, hospitals,**
#
#
# - Use the Overpass API with overpy2 Wrapper:
#
# This will help you fetch data from OSM. You might need to learn the query language for the Overpass API, but there are plenty of examples online.
#
# - Consider Web Scraping for Additional Data:
#
# If you find that some geospatial data is not available on OSM or is inconsistent, you can consider using Selenium to scrape relevant websites. Remember to always check the website's robots.txt file and terms of service to ensure you're allowed to scrape it.
#
# - Check Local or National Data Portals:
#
# These portals, like Open Data DK for Denmark, might have datasets that are relevant to your analysis. They might offer direct downloads or APIs for data access.

# %% [markdown]
# # Overview of the code
# ### 1.: This section fethcing and structuring data for malls (for practical purposes, I started with just the malls)
# ### 2.: Generalized approach, applying same methods on schools, restaurants, public transportaton and hospitals
# ### 3.: Combine malls, schools, restaurant, public transporation and hospitals data

# %%
#pip install overpy
# Remove "#" from the above if you have not installed overpy yet.

# %% [markdown]
# ## 1. Data for malls

# %% [markdown]
# ### First, we collect data for malls

# %%
import overpy

api = overpy.Overpass()

# Query for shopping centers
result = api.query("""
[out:json];
(
  node["shop"="mall"](around:10000,55.6761,12.5683);
  way["shop"="mall"](around:10000,55.6761,12.5683);
  relation["shop"="mall"](around:10000,55.6761,12.5683);
);
(._;>;);
out body;
""")

# Structure the data
nodes = [{'name': center.tags.get('name', 'n/a'), 'location': (center.lon, center.lat)} for center in result.nodes]
ways = [{'name': way.tags.get('name', 'n/a'), 'nodes': [(node.lon, node.lat) for node in way.nodes]} for way in result.ways]

# For relations, fetch associated ways from the result
relations = []
for relation in result.relations:
    relation_ways = [way for way in result.ways if way.id in [member.ref for member in relation.members if member.role == "outer"]]
    relations.append({'name': relation.tags.get('name', 'n/a'), 'ways': relation_ways})

# %%
def get_centroid(nodes):
    """Calculate the centroid of a list of nodes."""
    x_coords = [node[0] for node in nodes]
    y_coords = [node[1] for node in nodes]
    centroid_x = sum(x_coords) / len(nodes)
    centroid_y = sum(y_coords) / len(nodes)
    return (centroid_x, centroid_y)

malls_centroids = {}

# Handle nodes:
for node in nodes:
    mall_name = node['name']
    if mall_name not in malls_centroids:
        malls_centroids[mall_name] = node['location']

# Handle ways:
for way in ways:
    mall_name = way['name']
    if mall_name not in malls_centroids:
        malls_centroids[mall_name] = get_centroid(way['nodes'])

# Handle relations:
for relation in relations:
    mall_name = relation['name']
    if mall_name not in malls_centroids:
        # For each way in the relation, retrieve its nodes and calculate its centroid
        relation_centroids = [get_centroid([(node.lon, node.lat) for node in way.nodes]) for way in relation['ways']]
        malls_centroids[mall_name] = get_centroid(relation_centroids)

print(malls_centroids)
# Out:
# {'n/a': (Decimal('12.5310490'), Decimal('55.6818036')), 'Frederiksberg centeret': (Decimal('12.5333550'), Decimal('55.6822430')), 'Q-Park Illum': (Decimal('12.5795608'), Decimal('55.6797769')), 'K': (Decimal('12.4571370'), Decimal('55.6789057')), 'P': (Decimal('12.4579915'), Decimal('55.6799249')), 'Frihedens Butikscenter': (Decimal('12.48406003333333333333333333'), Decimal('55.626984875')), 'Frederiksberg Centret': (Decimal('12.53223812962962962962962963'), Decimal('55.68172073703703703703703704')), 'Rødovre Centrum': (Decimal('12.457133042'), Decimal('55.679388752')), 'Fisketorvet': (Decimal('12.56121518604651162790697674'), Decimal('55.66183853720930232558139535')), "Field's": (Decimal('12.57764880588235294117647059'), Decimal('55.63046102352941176470588235')), 'Nørrebro Bycenter': (Decimal('12.53812059622641509433962264'), Decimal('55.70324353207547169811320755')), 'Hvidovrevejs Butikstorv': (Decimal('12.4740983'), Decimal('55.65329371')), 'Hvidovre C': (Decimal('12.47597121071428571428571429'), Decimal('55.66354322142857142857142857')), 'Rebæk Søpark Butikscenter': (Decimal('12.45805314'), Decimal('55.6635152')), 'Waterfront Shopping': (Decimal('12.57936284'), Decimal('55.7258382')), 'Høje Gladsaxe Center': (Decimal('12.4973360'), Decimal('55.72994414')), 'Bangs Torv': (Decimal('12.43898987826086956521739130'), Decimal('55.7226910')), 'Spinderiet': (Decimal('12.51136917674418604651162791'), Decimal('55.66478501162790697674418605')), 'Amager Centret': (Decimal('12.604195236'), Decimal('55.663206452')), 'BIG Shopping': (Decimal('12.44850770625'), Decimal('55.71844340625')), 'Kronen Vanløse': (Decimal('12.49240612448979591836734694'), Decimal('55.68769317755102040816326531')), 'Illum': (Decimal('12.58036978181818181818181818'), Decimal('55.67946005454545454545454545')), 'Tårnby Torv': (Decimal('12.60082524'), Decimal('55.63061632')), 'Herlev Bymidte': (Decimal('12.43945772478260869565217392'), Decimal('55.7236510347826086956521739'))}

# %% [markdown]
# ### 2. Now, we collect for the rest using same method

# %% [markdown]
# **Data Collection**

# %%
import overpy

api = overpy.Overpass()

def get_data_for_amenity(amenity, around_distance=10000, lat=55.6761, lon=12.5683):
    query = f"""
    [out:json];
    (
      node["amenity"="{amenity}"](around:{around_distance},{lat},{lon});
      way["amenity"="{amenity}"](around:{around_distance},{lat},{lon});
      relation["amenity"="{amenity}"](around:{around_distance},{lat},{lon});
    );
    (._;>;);
    out body;
    """
    return api.query(query)

school_data = get_data_for_amenity("school")
restaurant_data = get_data_for_amenity("restaurant")
bus_station_data = get_data_for_amenity("bus_station")
train_station_data = get_data_for_amenity("railway", "station")
hospital_data = get_data_for_amenity("hospital")

# %% [markdown]
# ### Structure the data

# %%
def structure_data(raw_data):
    # Nodes
    nodes = [{'name': node.tags.get('name', 'n/a'), 'location': (node.lon, node.lat)} for node in raw_data.nodes]
    
    # Ways
    ways = [{'name': way.tags.get('name', 'n/a'), 'nodes': [(node.lon, node.lat) for node in way.nodes]} for way in raw_data.ways]
    
    # Relations
    relations = []
    for relation in raw_data.relations:
        relation_ways = [way for way in raw_data.ways if way.id in [member.ref for member in relation.members if member.role == "outer"]]
        relations.append({'name': relation.tags.get('name', 'n/a'), 'ways': relation_ways})
    
    return nodes, ways, relations

schools_nodes, schools_ways, schools_relations = structure_data(school_data)
restaurants_nodes, restaurants_ways, restaurants_relations = structure_data(restaurant_data)
bus_stations_nodes, bus_stations_ways, bus_stations_relations = structure_data(bus_station_data)
train_stations_nodes, train_stations_ways, train_stations_relations = structure_data(train_station_data)
hospitals_nodes, hospitals_ways, hospitals_relations = structure_data(hospital_data)

# %% [markdown]
# ### Compute Centroids

# %%
def extract_centroids_from_parsed_data(nodes, ways, relations):
    centroids = {}

    # Handle nodes:
    for node in nodes:
        name = node['name']
        if name not in centroids:
            centroids[name] = node['location']

    # Handle ways:
    for way in ways:
        name = way['name']
        if name not in centroids:
            centroids[name] = get_centroid(way['nodes'])

    # Handle relations:
    for relation in relations:
        name = relation['name']
        if name not in centroids and relation['ways']:
            relation_centroids = [get_centroid([(node.lon, node.lat) for node in way.nodes]) for way in relation['ways']]
            centroids[name] = get_centroid(relation_centroids) or "No Centroid"

    return centroids

schools_centroids = extract_centroids_from_parsed_data(schools_nodes, schools_ways, schools_relations)
restaurants_centroids = extract_centroids_from_parsed_data(restaurants_nodes, restaurants_ways, restaurants_relations)
bus_stations_centroids = extract_centroids_from_parsed_data(bus_stations_nodes, bus_stations_ways, bus_stations_relations)
train_stations_centroids = extract_centroids_from_parsed_data(train_stations_nodes, train_stations_ways, train_stations_relations)
hospitals_centroids = extract_centroids_from_parsed_data(hospitals_nodes, hospitals_ways, hospitals_relations)

print("Schools:", schools_centroids)
print("Restaurants:", restaurants_centroids)
print("Bus Stations:", bus_stations_centroids)
print("Train Stations:", train_stations_centroids)
print("Hospitals:", hospitals_centroids)
# Out:
# Schools: {'n/a': (Decimal('12.6255513'), Decimal('55.6337732')), 'Instituttet for Blinde og Svagsynede - IBOS': (Decimal('12.5634854'), Decimal('55.7267963')), 'Fritidshjemmet Ærtebjerg': (Decimal('12.4628603'), Decimal('55.6350689')), 'Skolen på Nyelandsvej': (Decimal('12.5303254'), Decimal('55.6828139')), 'Trekronergade Freinetskole': (Decimal('12.5197857'), Decimal('55.6572129')), 'Skolen ved Milestedet': (Decimal('12.4506967'), Decimal('55.6700978')), 'Niels Brock': (Decimal('12.5745879'), Decimal('55.6825046')), 'Flyvevåbnets Officersskole': (Decimal('12.5730322'), Decimal('55.7174668')), "Krebs' Skole": (Decimal('12.5757128'), Decimal('55.6898694')), 'Christianshavn Døttreskole': (Decimal('12.5939114'), Decimal('55.6733005')), 'Frederiksberg HF-kursus': (Decimal('12.4985739'), Decimal('55.6799579')), 'Gefion Gymnasium': (Decimal('12.5813831'), Decimal('55.6882961')), 'Prins Henriks Skole': (Decimal('12.5496938'), Decimal('55.6739171')), 'Fabrikken': (Decimal('12.6141227'), Decimal('55.6227549')), 'Københavns Idrætsefterskole': (Decimal('12.5112820'), Decimal('55.6479492')), 'Professionsskolen UCC': (Decimal('12.5533850'), Decimal('55.7043636')), 'Sprogcenter Hellerup': (Decimal('12.5566685'), Decimal('55.7274179')), 'Sprogcenter Hellerup - Tuborg campus': (Decimal('12.5788001'), Decimal('55.7267087')), 'Frederiksberg Slot - Hærens Officersskole': (Decimal('12.5251621'), Decimal('55.6718932')), 'High school': (Decimal('12.5735394'), Decimal('55.6752860')), 'Sosu C': (Decimal('12.4188799'), Decimal('55.6509471')), 'Engskolen': (Decimal('12.5455600'), Decimal('55.6683000')), 'Filipskolen': (Decimal('12.6334808'), Decimal('55.6595148')), 'Skandinavisk Yoga og Meditationsskole': (Decimal('12.5744800'), Decimal('55.6818700')), 'Amager International School': (Decimal('12.6349351'), Decimal('55.6481094')), 'Atheneskolen': (Decimal('12.4833149'), Decimal('55.7378603')), 'Borgens Køreskole': (Decimal('12.5206198'), Decimal('55.7306777')), 'Studieskolen': (Decimal('12.5845717'), Decimal('55.6826836')), 'Johan Borups Højskole': (Decimal('12.5774340'), Decimal('55.6738033')), 'Improv Comedy Copenhagen': (Decimal('12.5747590'), Decimal('55.6759970')), 'Københavns Madhus': (Decimal('12.5632535'), Decimal('55.6675422')), 'Frederiksberg Seminarium': (Decimal('12.5293170'), Decimal('55.6830990')), 'Søværnets Officersskole': (Decimal('12.5715928'), Decimal('55.7173559')), 'Forsvarsakademiet': (Decimal('12.5731891'), Decimal('55.7176443')), 'Goethe Institut': (Decimal('12.5731850'), Decimal('55.6827557')), 'Institut Sankt Joseph': (Decimal('12.5822440'), Decimal('55.6941452')), 'Teater butikken': (Decimal('12.5628584'), Decimal('55.6681532')), 'CPH Cooking Class': (Decimal('12.5897706'), Decimal('55.6791516')), 'Sunrise International Preschool': (Decimal('12.5702192'), Decimal('55.7258519')), 'SingularityU Nordic': (Decimal('12.5534944'), Decimal('55.7043392')), 'Hvidovre Musikskole': (Decimal('12.4761544'), Decimal('55.6489521')), 'Skolen på Strandboulevarden': (Decimal('12.5880004'), Decimal('55.7023037')), 'FGU Hovedstaden - Valby': (Decimal('12.5040440'), Decimal('55.6583890')), 'Københavns Professionshøjskole': (Decimal('12.5372896'), Decimal('55.6640976')), 'JUC SERVICE': (Decimal('12.5646570'), Decimal('55.6749490')), 'Den Grønne Friskole': (Decimal('12.6213089'), Decimal('55.6644583')), 'Langelinieskolen Holsteinsgade': (Decimal('12.5865382'), Decimal('55.6995722')), 'Fensmarkskolen': (Decimal('12.5521220'), Decimal('55.6958778')), 'Det frie Gymnasium': (Decimal('12.5454588'), Decimal('55.6891376')), 'Østerbro Lilleskole': (Decimal('12.5801014'), Decimal('55.7108408')), 'Terrible': (Decimal('12.5404065'), Decimal('55.6784806')), 'TEC Frederiksberg': (Decimal('12.5190374'), Decimal('55.6828992')), 'European School Copenhagen': (Decimal('12.5338545'), Decimal('55.6669100')), 'NEXT': (Decimal('12.5405445'), Decimal('55.7184481')), 'Afdeling hvidovre FGU Vestegnen': (Decimal('12.4494932'), Decimal('55.6324046')), 'FGU Hovedstaden - Øste ...
# Restaurants: {'Nørrebro Bryghus Restaurant': (Decimal('12.5639074'), Decimal('55.6902172')), 'Ingolfs Kaffebar': (Decimal('12.6119742'), Decimal('55.6501334')), 'Rio Bravo': (Decimal('12.5730625'), Decimal('55.6742501')), "Sticks'n'Sushi": (Decimal('12.5547131'), Decimal('55.6697106')), 'Viet Nam Nam': (Decimal('12.5376527'), Decimal('55.6856353')), 'Kafe Kapers': (Decimal('12.5768017'), Decimal('55.7050842')), 'Wagamama': (Decimal('12.5690757'), Decimal('55.6722759')), 'Il Ponte': (Decimal('12.5718891'), Decimal('55.6765807')), 'Wining & Dining': (Decimal('12.5754143'), Decimal('55.6797762')), 'Ristorante Amalfi': (Decimal('12.5753490'), Decimal('55.6794330')), 'Peder Oxe': (Decimal('12.5759776'), Decimal('55.6796537')), 'Bøf & Ost': (Decimal('12.5759530'), Decimal('55.6795485')), 'Cafe Victor': (Decimal('12.5832761'), Decimal('55.6807127')), 'Madklubben Grill': (Decimal('12.5804521'), Decimal('55.6803781')), 'La Vecchia Signora': (Decimal('12.5824969'), Decimal('55.6809107')), "L'Alsace": (Decimal('12.5828713'), Decimal('55.6807191')), 'Mama Rosa': (Decimal('12.5805759'), Decimal('55.6790105')), "Jensen's Bøfhus Axeltorv": (Decimal('12.5644933'), Decimal('55.6763037')), 'La Galette': (Decimal('12.5695321'), Decimal('55.6778757')), "L'education Nationale": (Decimal('12.5697430'), Decimal('55.6782280')), 'Dubrovnik': (Decimal('12.5680739'), Decimal('55.6781715')), "Jensen's Bøfhus": (Decimal('12.5616617'), Decimal('55.6733149')), 'Deep': (Decimal('12.5977260'), Decimal('55.6668710')), 'Rimini': (Decimal('12.5971417'), Decimal('55.6681601')), "Krog's Fiskerestaurant": (Decimal('12.5785538'), Decimal('55.6777413')), 'Ankara': (Decimal('12.5741096'), Decimal('55.6811269')), 'Eros': (Decimal('12.5752015'), Decimal('55.6793725')), 'Nova': (Decimal('12.5737580'), Decimal('55.6791314')), 'Shahi': (Decimal('12.5727364'), Decimal('55.6787069')), 'Hong Cheng': (Decimal('12.5754032'), Decimal('55.7089635')), 'Safir Kebab': (Decimal('12.5441844'), Decimal('55.6904980')), 'Els': (Decimal('12.5878215'), Decimal('55.6809684')), 'Zeleste': (Decimal('12.5883161'), Decimal('55.6809061')), 'Italiano': (Decimal('12.5738811'), Decimal('55.6792833')), 'Wok On': (Decimal('12.5803408'), Decimal('55.6780529')), 'Restaurant Jacobsen': (Decimal('12.5745415'), Decimal('55.6826871')), 'Marv & Ben': (Decimal('12.5769463'), Decimal('55.6772838')), 'Le Basilic': (Decimal('12.5562393'), Decimal('55.6719106')), 'Apropos': (Decimal('12.5610473'), Decimal('55.6707876')), 'Ban Gaw': (Decimal('12.5573535'), Decimal('55.6690839')), 'Porn-Sak': (Decimal('12.5577022'), Decimal('55.6692654')), 'Beijing': (Decimal('12.5703318'), Decimal('55.6770342')), "Flora's Steakhouse": (Decimal('12.5596734'), Decimal('55.6733045')), 'La Fiesta Mexicana': (Decimal('12.5452292'), Decimal('55.6732568')), 'Akropolis': (Decimal('12.5515978'), Decimal('55.6843632')), 'Nyu Sakura': (Decimal('12.5514227'), Decimal('55.6841005')), 'Radio': (Decimal('12.5543323'), Decimal('55.6819882')), 'Nytorv': (Decimal('12.5736687'), Decimal('55.6772100')), 'Zafran': (Decimal('12.5595118'), Decimal('55.6873787')), 'Salt': (Decimal('12.5941964'), Decimal('55.6820201')), 'Café Le perr Valby': (Decimal('12.5150828'), Decimal('55.6665230')), 'Hotel Fy & Bi': (Decimal('12.5145524'), Decimal('55.6664428')), 'Pintxos': (Decimal('12.5660522'), Decimal('55.6844442')), 'Altopalato': (Decimal('12.5738669'), Decimal('55.7360678')), 'Le Saint Jacques': (Decimal('12.5779306'), Decimal('55.7034223')), 'Sushi Nørregade': (Decimal('12.5712029'), Decimal('55.6818262')), "Sticks'N'Sushi": (Decimal('12.5647608'), Decimal('55.6841991')), 'Cafe Munk': (Decimal('12.5673006'), Decimal('55.6843897')), 'Restaurant Koefoed': (Decimal('12.5854059'), Decimal('55.6829182')), 'Cantina': (Decimal('12.5841755'), Decimal('55.6823201')), 'Allegade 10': (Decimal('12.5332170'), Decimal('55.6760001')), 'Kreta III': (Decimal('12.4838727'), Decimal('55.6919588')), 'Chaophraya': (Decimal('12.5071737'), Decimal('55.6931331')), "Sticks'N'Sushi V ...
# Bus Stations: {'Friheden St.': (Decimal('12.4826907'), Decimal('55.6287324')), 'n/a': (Decimal('12.5429007'), Decimal('55.7453596')), 'Flintholm St.': (Decimal('12.4986859'), Decimal('55.6859951')), 'Buddinge St.': (Decimal('12.4943113'), Decimal('55.7467772')), 'Port Copenhague': (Decimal('12.5958280'), Decimal('55.7014409')), 'Flixbus': (Decimal('12.5654374'), Decimal('55.6700329')), 'Nøragersmindevej': (Decimal('12.58163447'), Decimal('55.5914446'))}
# Train Stations: {}
# Hospitals: {'n/a': (Decimal('12.6215270'), Decimal('55.6561274')), 'Børneneurologisk Behandlingsklinik': (Decimal('12.5658320'), Decimal('55.7156153')), 'Privathospitalet Danmark': (Decimal('12.5717780'), Decimal('55.7536114')), 'Psykiatrisk akutmodtagelse': (Decimal('12.5217996'), Decimal('55.6858367')), 'Psykiatrisk Center Frederiksberg': (Decimal('12.5209950'), Decimal('55.6861512')), 'Akutklinik': (Decimal('12.5257885'), Decimal('55.6872847')), 'Blod Bank': (Decimal('12.5460507'), Decimal('55.7383383')), 'Børne- og Ungdomspsykiatrisk Center': (Decimal('12.5434342'), Decimal('55.7158717')), 'Amager Hospital - Italiensvej': (Decimal('12.62034851'), Decimal('55.65509039')), 'Diakonisse-stiftelsen': (Decimal('12.51808739285714285714285714'), Decimal('55.67842625')), 'Gentofte Hospital': (Decimal('12.54680505217391304347826087'), Decimal('55.7384367')), 'Bispebjerg Hospital': (Decimal('12.54081872'), Decimal('55.714623285')), 'Hvidovre Hospital': (Decimal('12.46602502222222222222222222'), Decimal('55.64899323333333333333333333')), 'Steno Diabetes Center Copenhagen': (Decimal('12.52641321428571428571428571'), Decimal('55.75577249285714285714285714')), 'Rigshospitalet': (Decimal('12.56484704285714285714285714'), Decimal('55.69752517142857142857142857')), 'Psykiatrisk Center Glostrup (afdeling Hvidovre)': (Decimal('12.44133486'), Decimal('55.64918801')), 'Psykiatrisk Center Amager': (Decimal('12.58598378907849829351535836'), Decimal('55.64332622252559726962457338')), 'Amager Hospital - Hans Bogbinders Allé': (Decimal('12.60833514444444444444444444'), Decimal('55.65450875555555555555555556')), 'Herlev Hospital': (Decimal('12.44206964130434782608695652'), Decimal('55.73196666304347826086956522')), 'Frederiksberg Hospital': (Decimal('12.52292147647058823529411765'), Decimal('55.68672727647058823529411765'))}

# %% [markdown]
# ### 3.: Now we combine the data and write to a CSV file

# %%
import csv

# Combine all data
all_centroids = {
    "Malls": malls_centroids,
    "Schools": schools_centroids,
    "Restaurants": restaurants_centroids,
    "Bus Stations": bus_stations_centroids,
    "Train Stations": train_stations_centroids,
    "Hospitals": hospitals_centroids
}

# Write data to CSV with UTF-8 encoding
with open("geospatial_data_wrong_order.csv", "w", newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    # Write header
    writer.writerow(["Type", "Name", "Longitude", "Latitude"])
    
    for category, centroids in all_centroids.items():
        for name, location in centroids.items():
            if location != "No Centroid":
                writer.writerow([category, name, location[0], location[1]])
            else:
                writer.writerow([category, name, "No Centroid", "No Centroid"])

print("Data written to 'geospatial_data_wrong_order.csv'")
# Out:
# Data written to 'geospatial_data_wrong_order.csv'

# %%
import pandas as pd

# Assuming you've loaded your data into a DataFrame named 'df'
df = pd.read_csv('geospatial_data_wrong_order.csv')

# Reordering the columns
df = df[['Type', 'Name', 'Latitude', 'Longitude']]

# Saving it back to the CSV (or to a new CSV if you prefer)
df.to_csv('geospatial_data_right_order.csv', index=False)
